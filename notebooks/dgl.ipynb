# %% [markdown]
# Notes from https://github.com/Junyoungpark/GNNAtoZ

# %% [markdown]
# # 0. Bring Your Own Graphs

# %%
## Instantiating a graph  
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph() # instantiate an empty container for handling graph
G.add_node(1) # Add node in the graph
G.add_node(2) # Add node in the graph
G.add_node(3) # Add node in the graph

G.add_edge(1,2)
G.add_edge(2,3)

nx.draw(G)

# %%
## DGL

import dgl
import torch

# %%
# edges 0->1, 0->2, 0->3, 1->3
u, v = torch.tensor([0, 0, 0, 1]), torch.tensor([1, 2, 3, 3])
g = dgl.graph((u, v))
print(g)

# %%
g = dgl.graph((u, v), num_nodes=8)
print(g)

# %%
node_feat_dim = 7 # the node feature dim
edge_feat_dim = 3 # the edge feature dim

g.ndata['feat'] = torch.randn(g.number_of_nodes(), node_feat_dim)
g.edata['feat'] = torch.randn(g.number_of_edges(), edge_feat_dim)
print(g)

# %%
def plot_dgl_graph(g):
    G = dgl.to_networkx(g)
    plt.figure(figsize=[10,5])
    options = {
        'node_color': 'blue',
        "edge_color": "red",
        'node_size': 20,
        'width': 1,
    }
    # pos = nx.spring_layout(g)
    # nx.draw_networkx(g, pos, **options)
    nx.draw(G, **options)
    plt.show()

# %%
plot_dgl_graph(g)

# %% [markdown]
# # 1. Message Passing on DGL

# %%
import dgl
import torch
import torch.nn as nn

# %%
u, v = torch.tensor([0, 0, 0, 1]), torch.tensor([1, 2, 3, 3])
g = dgl.graph((u, v), num_nodes=8)
g = dgl.add_self_loop(g)

node_feat_dim = 32
edge_feat_dim = 3

g.ndata["feat"] = torch.randn(g.number_of_nodes(), node_feat_dim)
g.edata["feat"] = torch.randn(g.number_of_edges(), edge_feat_dim)

print(g)

# %%
class MessagePassingGCN(nn.Module):
    def __init__(self, input_dim: int, output_dim: int):
        super(MessagePassingGCN, self).__init__()
        self.linear = nn.Linear(in_features=input_dim, out_features=output_dim, bias=False)

    def forward(self, g, nf):
        g = g.local_var() # make a local graph
        z = self.linear(nf)
        g.ndata["z"] = z

        g.pull(v=g.nodes(), message_func=self.message_func, reduce_func=self.reduce_func)
        
        # The operations happens in `g.pull`
        # 1. Message generation: In this case, the message is "source node feature."
        # 2. 'Push' the message to the destination nodes
        # 3. 'Reduce' the messages from the destination nodes
        # 4. Perform node update: In this case, we don't do.
        
        # For further details, refer to the dgl's API documents. 
        return g.ndata["h"]

    def message_func(self, edges):
        return {"z": edges.src["z"]}

    def reduce_func(self, nodes):
        return {"h": torch.sum(nodes.mailbox["z"], dim=1)}

# %%
gc_out_dim = 256
gc = MessagePassingGCN(node_feat_dim, gc_out_dim)

# %%
h_updated = gc(g, g.ndata['feat'])
print(h_updated.shape)

# %%
# %%timeit
h_updated = gc(g, g.ndata['feat'])

# %%
# A slightly optimized verision of the simple GCN with dgl.function

class MessagePassingGCN(nn.Module):
    def __init__(self, input_dim: int, output_dim: int):
        super(MessagePassingGCN, self).__init__()
        self.linear = nn.Linear(in_features=input_dim, out_features=output_dim, bias=False)
        self.message_func = dgl.function.copy_src("z", "z")
        self.reduce_func = dgl.function.sum("z", "h")

    def forward(self, g, nf):
        g = g.local_var()
        z = self.linear(nf)
        g.ndata["z"] = z

        g.pull(v=g.nodes(), message_func=self.message_func, reduce_func=self.reduce_func)
        return g.ndata["h"]

# %%
gc = MessagePassingGCN(node_feat_dim, gc_out_dim)

# %%
h_updated = gc(g, g.ndata['feat'])
print(h_updated.shape)

# %%
# %%timeit
h_updated = gc(g, g.ndata['feat'])

# %% [markdown]
# # 2. Implement Famous GNNs

# %%
import dgl
import torch
import dgl.nn.pytorch.conv as dglconv

# %%
u, v = torch.tensor([0, 0, 0, 1]), torch.tensor([1, 2, 3, 3])
g = dgl.graph((u, v), num_nodes=8)
g = dgl.add_self_loop(g)

node_feat_dim = 32
edge_feat_dim = 3

g.ndata['feat'] = torch.randn(g.number_of_nodes(), node_feat_dim)
g.edata['feat'] = torch.randn(g.number_of_edges(), edge_feat_dim)

# %%
gc_out_dim = 16

gc = dglconv.GraphConv(in_feats=node_feat_dim, out_feats=gc_out_dim)

# %%
h_updated = gc(g, g.ndata['feat'])

# %%
# Graph Attention Networks
gat = dglconv.GATConv(in_feats=node_feat_dim,
                      out_feats=gc_out_dim,
                      num_heads=4)

# %%
h_updated_gat = gat(g, g.ndata['feat'])

# %%
h_updated_gat.shape # [#.nodes x #. attn head x # out dim]

# %%
g.ndata['feat']

# %%
# mini batch

batched_g = dgl.batch([g, g])

# %%
print("Number of graphs in the batched graphs : {} \n".format(batched_g.batch_size))

print("Total number of nodes : {}".format(batched_g.num_nodes()))
print("Total number of edges : {} \n".format(batched_g.num_edges()))
n_nodes = [i.item() for i in batched_g.batch_num_nodes()]
n_edges = [i.item() for i in batched_g.batch_num_edges()]

print("Per graph number of nodes : {}".format(n_nodes))
print("Per graph number of edges : {} \n".format(n_edges))

# %%
h_updated_batched = gc(batched_g, batched_g.ndata['feat'])
print(h_updated_batched.shape) # take a look at that the first dimension of output is now doubled.

# %%
# Graph Readouts

readout = h_updated.sum(dim=0)
print(readout.shape)
print(readout)

# %%
g.ndata['updated_h'] = h_updated
readout = dgl.readout_nodes(g, 'updated_h', op='sum')

# %%
print(readout.shape)
print(readout)

# %% [markdown]
# # 3. How to train GraphSAGE

# %%
import torch
import dgl
import torch.nn as nn
import dgl.nn as dglnn
import torch.nn.functional as F

# %%
dataset = dgl.data.CiteseerGraphDataset()
graph = dataset[0] # since it only has one graph :)

# %%
plot_dgl_graph(graph)

# %%
# %%latex
# \begin{equation}
# h=\text{GraphSAGE}^{(2)}(\text{ReLU}((\text{GraphSAGE}^{(1)}(\mathcal{G}, X))))
# \end{equation}

# %%
class SAGE(nn.Module):
    def __init__(self, in_feats, hid_feats, out_feats):
        super().__init__()
        self.conv1 = dglnn.SAGEConv(in_feats, hid_feats, aggregator_type="mean")
        self.conv2 = dglnn.SAGEConv(hid_feats, out_feats, aggregator_type="mean")

    def forward(self, g, inputs):
        h = self.conv1(g, inputs)
        h = F.relu(h)
        h = self.conv2(g, h)
        return h

# %%
graph.ndata.keys()

# %%
node_features = graph.ndata["feat"]
node_labels = graph.ndata["label"]
train_mask = graph.ndata["train_mask"]
val_mask = graph.ndata["val_mask"]
test_mask = graph.ndata["test_mask"]

n_features = node_features.shape[1]
n_labels = len(node_labels.unique())

# %%
def evaluate(model, graph, features, labels, mask):
    model.eval()
    with torch.no_grad():
        logits = model(graph, features)
        logits = logits[mask]
        labels = labels[mask]
        _, indices = torch.max(logits, dim=1)
        correct = torch.sum(indices == labels)
        return correct.item() * 1.0 / len(labels)

# %%
model = SAGE(in_feats=n_features, hid_feats=100, out_feats=n_labels)
opt = torch.optim.Adam(model.parameters())

for epoch in range(100):
    model.train()
    # forward prop by using all nodes
    logits = model(graph, node_features)
    # compute loss
    loss = F.cross_entropy(logits[train_mask], node_labels[train_mask])
    
    # compute train & validation accuracy
    train_acc = evaluate(model, graph, node_features, node_labels, train_mask)
    val_acc = evaluate(model, graph, node_features, node_labels, val_mask)
    # backward prop
    opt.zero_grad()
    loss.backward()
    opt.step()
    print("Epoch {:05d} | Loss {:.4f} | Train Acc {:.4f} | Val Acc {:.4f}".format(
        epoch, loss.item(), train_acc, val_acc))

# %%
model(graph, node_features)

# %%
logits = model(graph, node_features)
logits

# %%
logits.max()

# %% [markdown]
# # Tensorflow Implementation

# %%
import os; os.environ["DGLBACKEND"] = "tensorflow"

# %%
import dgl

# %%
import pandas as pd
df = pd.read_parquet("../data/processed/outlier_removed.parquet")

# %%
# corr based adjacency

data = df[["forecast_dt", "rt_plant_id", "production"]]
data = pd.pivot_table(data, index="forecast_dt", columns="rt_plant_id", values="production")

# %%
import dgl
from dgl.data import DGLDataset
import tensorflow as tf
import numpy as np

class WindPowerDataset(DGLDataset):
    def __init__(self):
        super().__init__(name="wind")

    def process(self):
        df = pd.read_parquet("data/wind/2019-01-24_outlier_removed.parquet")    
        weather_cols = [col for col in df.columns if col.startswith(("UGRD", "VGRD"))]
        plant_mapping = {k:v for k,v in zip(np.sort(df.rt_plant_id.astype(int).unique()), range(df.rt_plant_id.nunique()))}
        df.rt_plant_id = df.rt_plant_id.map(plant_mapping)
        
        THRESHOLD = 0.5
        edges_data = df[["forecast_dt", "rt_plant_id", "production"]]
        edges_data = pd.pivot_table(edges_data, index="forecast_dt", columns="rt_plant_id", values="production")
        A = abs(edges_data.corr())
        A = A[A > THRESHOLD].fillna(0)
        long_df = pd.DataFrame()
        for i, row in A.iterrows():
            df_ = pd.DataFrame(list(zip(row.index, row)), columns=["Dst", "Weight"])
            df_ = df_[df_["Weight"] != 0]
            df_ = df_[df_["Dst"] != i]
            df_["Src"] = i
            long_df = long_df.append(df_)
        edges_data = long_df.reset_index(drop=True)[["Src", "Dst", "Weight"]]
        edge_features = tf.convert_to_tensor(edges_data['Weight'].numpy(), dtype=tf.float32)
        # edge_features = torch.from_numpy(edges_data['Weight'].to_numpy())
        edges_src = tf.convert_to_tensor(edges_data['Src'].numpy(), dtype=tf.float32)
        edges_dst = tf.convert_to_tensor(edges_data['Dst'].numpy(), dtype=tf.float32)
        
        nodes_data = df[["rt_plant_id", "forecast_dt", "production", *weather_cols]]
        nodes_data = nodes_data.reset_index(drop=True)
        nodes_data = nodes_data[nodes_data["forecast_dt"] == nodes_data["forecast_dt"].min()]
        node_features = tf.convert_to_tensor(nodes_data[weather_cols].numpy())
        node_labels = tf.convert_to_tensor(nodes_data["production"].numpy())
        
        self.graph = dgl.graph((edges_src, edges_dst), num_nodes=nodes_data.shape[0])
        self.graph.ndata['feat'] = node_features
        self.graph.ndata['label'] = node_labels
        self.graph.edata['weight'] = edge_features

        
    def __getitem__(self, i):
        return self.graph

    def __len__(self):
        return 1

# %% [markdown]
# # Pytorch Implementation

# %%
import dgl
import pandas as pd
df = pd.read_parquet("../data/processed/outlier_removed.parquet")
# Out:
# [19:28:50Using backend: pytorch
# ] /opt/dgl/src/runtime/tensordispatch.cc:43: TensorDispatcher: dlopen failed: /home/mert/miniconda3/envs/thesis_torch/lib/python3.9/site-packages/dgl/tensoradapter/pytorch/libtensoradapter_pytorch_1.10.2.so: cannot open shared object file: No such file or directory

# %%
import scipy.sparse as sp
THRESHOLD = 0.5

edges_data = df[["forecast_dt", "rt_plant_id", "production"]]
A = abs(edges_data.corr())
A = A[A > THRESHOLD].fillna(0)
sp_mx = sp.coo_matrix(A)
G = dgl.from_scipy(sp_mx, eweight_name="weight")
G.adjacency_matrix()
# print(G.edata["weight"])
# Out:
# tensor(indices=tensor([[0, 1],
#                        [0, 1]]),
#        values=tensor([1., 1.]),
#        size=(2, 2), nnz=2, layout=torch.sparse_coo)

# %%
import dgl
from dgl.data import DGLDataset
import torch
import numpy as np

class WindPowerDataset(DGLDataset):
    def __init__(self):
        super().__init__(name="wind")

    def process(self):
        df = pd.read_parquet("../data/processed/outlier_removed.parquet")    
        weather_cols = [col for col in df.columns if col.startswith(("UGRD", "VGRD"))]
        plant_mapping = {k:v for k,v in zip(np.sort(df.rt_plant_id.astype(int).unique()), range(df.rt_plant_id.nunique()))}
        df.rt_plant_id = df.rt_plant_id.map(plant_mapping)
        
        THRESHOLD = 0.5
        edges_data = df[["forecast_dt", "rt_plant_id", "production"]]
        edges_data = pd.pivot_table(edges_data, index="forecast_dt", columns="rt_plant_id", values="production")
        A = abs(edges_data.corr())
        A = A[A > THRESHOLD].fillna(0)
        long_df = pd.DataFrame()
        for i, row in A.iterrows():
            df_ = pd.DataFrame(list(zip(row.index, row)), columns=["Dst", "Weight"])
            df_ = df_[df_["Weight"] != 0]
            df_ = df_[df_["Dst"] != i]
            df_["Src"] = i
            long_df = long_df.append(df_)
        edges_data = long_df.reset_index(drop=True)[["Src", "Dst", "Weight"]]
        edge_features = torch.from_numpy(edges_data['Weight'].to_numpy())
        edges_src = torch.from_numpy(edges_data['Src'].to_numpy())
        edges_dst = torch.from_numpy(edges_data['Dst'].to_numpy())
        
        nodes_data = df[["rt_plant_id", "forecast_dt", "production", *weather_cols]]
        nodes_data = nodes_data.reset_index(drop=True)
        nodes_data = nodes_data[nodes_data["forecast_dt"] == nodes_data["forecast_dt"].min()]
        node_features = torch.from_numpy(nodes_data[weather_cols].to_numpy())
        node_labels = torch.from_numpy(nodes_data["production"].to_numpy())
        
        self.graph = dgl.graph((edges_src, edges_dst), num_nodes=nodes_data.shape[0])
        self.graph.ndata['feat'] = node_features
        self.graph.ndata['label'] = node_labels
        self.graph.edata['weight'] = edge_features

        
    def __getitem__(self, i):
        return self.graph

    def __len__(self):
        return 1

# %%
# https://github.com/dmlc/dgl/blob/master/examples/pytorch/gcn/gcn.py

"""GCN using DGL nn package
References:
- Semi-Supervised Classification with Graph Convolutional Networks
- Paper: https://arxiv.org/abs/1609.02907
- Code: https://github.com/tkipf/gcn
"""
import torch
import torch.nn as nn
from dgl.nn.pytorch import GraphConv

class GCN(nn.Module):
    def __init__(self,
                 g,
                 in_feats,
                 n_hidden,
                 n_classes,
                 n_layers,
                 activation,
                 dropout):
        super(GCN, self).__init__()
        self.g = g
        self.layers = nn.ModuleList()
        # input layer
        self.layers.append(GraphConv(in_feats, n_hidden, activation=activation))
        # hidden layers
        for i in range(n_layers - 1):
            self.layers.append(GraphConv(n_hidden, n_hidden, activation=activation))
        # output layer
        self.layers.append(GraphConv(n_hidden, n_classes))
        self.dropout = nn.Dropout(p=dropout)

    def forward(self, features):
        h = features
        for i, layer in enumerate(self.layers):
            if i != 0:
                h = self.dropout(h)
            h = layer(self.g, h)
        return h

# %%
import numpy as np
import torch
import torch.nn.functional as F
import dgl
from dgl.data import CoraGraphDataset

# %%
data = CoraGraphDataset() # len 1, num_nodes=2708, num_edges=10556

g = data[0]

features = g.ndata['feat']
labels = g.ndata['label']
train_mask = g.ndata['train_mask']
val_mask = g.ndata['val_mask']
test_mask = g.ndata['test_mask']
in_feats = features.shape[1]
n_classes = data.num_classes
n_edges = g.number_of_edges()
print("""----Data statistics------'
    #Edges %d
    #Classes %d
    #Train samples %d
    #Val samples %d
    #Test samples %d""" %
        (n_edges, n_classes,
            train_mask.int().sum().item(),
            val_mask.int().sum().item(),
            test_mask.int().sum().item()))
# Out:
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# ----Data statistics------'
#     #Edges 10556
#     #Classes 7
#     #Train samples 140
#     #Val samples 500
#     #Test samples 1000

# %%
g = dgl.remove_self_loop(g)
g = dgl.add_self_loop(g)
n_edges = g.number_of_edges()
print(n_edges)
# Out:
# 13264

# %%
degs = g.in_degrees().float()
norm = torch.pow(degs, -0.5)
norm[torch.isinf(norm)] = 0

# %%
g.ndata['norm'] = norm.unsqueeze(1)

# %%
args = {
    "n_hidden": 16,
    "dropout": 0.5,
    "n_layers": 1,
    "lr": 0.01,
    "n_epochs": 1000,
    "weight_decay": 5e-4
}

# %%
model = GCN(g,
            in_feats,
            args["n_hidden"],
            n_classes,
            args["n_layers"],
            F.relu,
            args["dropout"])

# %%
loss_fcn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(
    model.parameters(), lr=args["lr"], weight_decay=args["weight_decay"])

# %%
import time

def evaluate(model, features, labels, mask):
    model.eval()
    with torch.no_grad():
        logits = model(features)
        logits = logits[mask]
        labels = labels[mask]
        _, indices = torch.max(logits, dim=1)
        correct = torch.sum(indices == labels)
        return correct.item() * 1.0 / len(labels)


dur = []
for epoch in range(args["n_epochs"]):
    model.train()
    if epoch >= 3:
        t0 = time.time()
    # forward
    logits = model(features)
    loss = loss_fcn(logits[train_mask], labels[train_mask])

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch >= 3:
        dur.append(time.time() - t0)

    acc = evaluate(model, features, labels, val_mask)
    print("Epoch {:05d} | Time(s) {:.4f} | Loss {:.4f} | Accuracy {:.4f} | "
            "ETputs(KTEPS) {:.2f}". format(epoch, np.mean(dur), loss.item(),
                                            acc, n_edges / np.mean(dur) / 1000))

print()
acc = evaluate(model, features, labels, test_mask)
print("Test accuracy {:.2%}".format(acc))
# Out:
# /home/mert/miniconda3/envs/thesis_torch/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# /home/mert/miniconda3/envs/thesis_torch/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/mert/miniconda3/envs/thesis_torch/lib/python3.9/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Epoch 00000 | Time(s) nan | Loss 1.9454 | Accuracy 0.1460 | ETputs(KTEPS) nan
# Epoch 00001 | Time(s) nan | Loss 1.9400 | Accuracy 0.2900 | ETputs(KTEPS) nan
# Epoch 00002 | Time(s) nan | Loss 1.9332 | Accuracy 0.3960 | ETputs(KTEPS) nan
# Epoch 00003 | Time(s) 0.0082 | Loss 1.9232 | Accuracy 0.4180 | ETputs(KTEPS) 1612.93
# Epoch 00004 | Time(s) 0.0079 | Loss 1.9147 | Accuracy 0.5580 | ETputs(KTEPS) 1670.09
# Epoch 00005 | Time(s) 0.0083 | Loss 1.9053 | Accuracy 0.5980 | ETputs(KTEPS) 1603.00
# Epoch 00006 | Time(s) 0.0081 | Loss 1.8925 | Accuracy 0.6060 | ETputs(KTEPS) 1631.66
# Epoch 00007 | Time(s) 0.0079 | Loss 1.8821 | Accuracy 0.6180 | ETputs(KTEPS) 1688.38
# Epoch 00008 | Time(s) 0.0078 | Loss 1.8671 | Accuracy 0.6240 | ETputs(KTEPS) 1699.24
# Epoch 00009 | Time(s) 0.0078 | Loss 1.8608 | Accuracy 0.6320 | ETputs(KTEPS) 1709.68
# Epoch 00010 | Time(s) 0.0077 | Loss 1.8505 | Accuracy 0.6420 | ETputs(KTEPS) 1713.41
# Epoch 00011 | Time(s) 0.0078 | Loss 1.8322 | Accuracy 0.6520 | ETputs(KTEPS) 1695.41
# Epoch 00012 | Time(s) 0.0078 | Loss 1.8228 | Accuracy 0.6520 | ETputs(KTEPS) 1705.59
# Epoch 00013 | Time(s) 0.0076 | Loss 1.7951 | Accuracy 0.6600 | ETputs(KTEPS) 1734.12
# Epoch 00014 | Time(s) 0.0076 | Loss 1.7901 | Accuracy 0.6620 | ETputs(KTEPS) 1756.22
# Epoch 00015 | Time(s) 0.0075 | Loss 1.7723 | Accuracy 0.6640 | ETputs(KTEPS) 1770.75
# Epoch 00016 | Time(s) 0.0075 | Loss 1.7571 | Accuracy 0.6640 | ETputs(KTEPS) 1769.42
# Epoch 00017 | Time(s) 0.0075 | Loss 1.7379 | Accuracy 0.6700 | ETputs(KTEPS) 1767.86
# Epoch 00018 | Time(s) 0.0075 | Loss 1.7302 | Accuracy 0.6760 | ETputs(KTEPS) 1771.11
# Epoch 00019 | Time(s) 0.0075 | Loss 1.7042 | Accuracy 0.6740 | ETputs(KTEPS) 1773.45
# Epoch 00020 | Time(s) 0.0075 | Loss 1.6854 | Accuracy 0.6760 | ETputs(KTEPS) 1777.56
# Epoch 00021 | Time(s) 0.0075 | Loss 1.6855 | Accuracy 0.6820 | ETputs(KTEPS) 1778.25
# Epoch 00022 | Time(s) 0.0076 | Loss 1.6507 | Accuracy 0.6920 | ETputs(KTEPS) 1754.17
# Epoch 00023 | Time(s) 0.0076 | Loss 1.6395 | Accuracy 0.6980 | ETputs(KTEPS) 1738.66
# Epoch 00024 | Time(s) 0.0077 | Loss 1.6393 | Accuracy 0.7080 | ETputs(KTEPS) 1730.32
# Epoch 00025 | Time(s) 0.0077 | Loss 1.5988 | Accuracy 0.7120 | ETputs(KTEPS) 1722.54
# Epoch 00026 | Time(s) 0.0077 | Loss 1.5758 | Accuracy 0.7200 | ETputs(KTEPS) 1719.51
# Epoch 00027 | Time(s) 0.0077 | Loss 1.5638 | Accuracy 0.7220 | ETputs(KTEPS) 1723.53
# Epoch 00028 | Time(s) 0.0077 | Loss 1.5316 | Accuracy 0.7200 | ETputs(KTEPS) 1716.73
# Epoch 00029 | Time(s) 0.0077 | Loss 1.5300 | Accuracy 0.7160 | ETputs(KTEPS) 1717.44
# Epoch 00030 | Time(s) 0.0077 | Loss 1.5114 | Accuracy 0.7180 | ETputs(KTEPS) 1728.46
# Epoch 00031 | Time(s) 0.0076 | Loss 1.4907 | Accuracy 0.7220 | ETputs(KTEPS) 1738.79
# Epoch 00032 | Time(s) 0.0076 | Loss 1.4803 | Accuracy 0.7220 | ETputs(KTEPS) 1738.01
# Epoch 00033 | Time(s) 0.0076 | Loss 1.4525 | Accuracy 0.7220 | ETputs(KTEPS) 1747.06
# Epoch 00034 | Time(s) 0.0076 | Loss 1.4346 | Accuracy 0.7280 | ETputs(KTEPS) 1750.54
# Epoch 00035 | Time(s) 0.0076 | Loss 1.3980 | Accuracy 0.7320 | ETputs(KTEPS) 1752.32
# Epoch 00036 | Time(s) 0.0076 | Loss 1.3944 | Accuracy 0.7340 | ETputs(KTEPS) 1745.55
# Epoch 00037 | Time(s) 0.0076 | Loss 1.3537 | Accuracy 0.7320 | ETputs(KTEPS) 1747.51
# Epoch 00038 | Time(s) 0.0076 | Loss 1.3663 | Accuracy 0.7340 | ETputs(KTEPS) 1740.93
# Epoch 00039 | Time(s) 0.0076 | Loss 1.3198 | Accuracy 0.7340 | ETputs(KTEPS) 1736.88
# Epoch 00040 | Time(s) 0.0076 | Loss 1.3170 | Accuracy 0.7340 | ETputs(KTEPS) 1736.49
# Epoch 00041 | Time(s) 0.0076 | Loss 1.2737 | Accuracy 0.7380 | ETputs(KTEPS) 1740.58
# Epoch 00042 | Time(s) 0.0076 | Loss 1.2602 | Accuracy 0.7400 | ETputs(KTEPS) 1743.14
# Epoch 00043 | Time(s) 0.0076 | Loss 1.2508 | Accuracy 0.7400 | ETputs(KTEPS) 1746.51
# Epoch 00044 | Time(s) 0.0076 | Loss 1.2126 | Accuracy 0.7380 | ETputs(KTEPS) 1748.84
# Epoch 00045 | Time(s) 0.0076 | Loss 1.2305 | Accuracy 0.7400 | ETputs(KTEPS) 1756.05
# Epoch 00046 | Time(s) 0.0075 | Loss 1.1740 | Accuracy 0.7420 | ETputs(KTEPS) 1762.49
# Epoch 00047 | Time(s) 0.0075 | Loss 1.1465 | Accuracy 0.7380 | ETputs(KTEPS) 1768.55
# Epoch 00048 | Time(s) 0.0075 | Loss 1.1449 | Accuracy 0.7400 | ETputs(KTEPS) 1775.55
# Epoch 00049 | Time(s) 0.0075 | Loss 1.1090 | Accuracy 0.7440 | ETputs(KTEPS) 1780.37
# Epoch 00050 | Time(s) 0.0074 | Loss 1.0895 | Accuracy 0.7480 | ETputs(KTEPS) 1780.96
# Epoch 00051 | Time(s) 0.0074 | Loss 1.1046 | Accuracy 0.7500 | ETputs(KTEPS) 1783.62
# Epoch 00052 | Time(s) 0.0074 | Loss 1.0473 | Accuracy 0.7480 | ETputs(KTEPS) 1787.57
# Epoch 00053 | Time(s) 0.0074 | Loss 1.0593 | Accuracy 0.7440 | ETputs(KTEPS) 1787.41
# Epoch 00054 | Time(s) 0.0075 | Loss 1.0687 | Accuracy 0.7500 | ETputs(KTEPS) 1779.91
# Epoch 00055 | Time(s) 0.0074 | Loss 1.0093 | Accuracy 0.7540 | ETputs(KTEPS) 1783.14
# Epoch 00056 | Time(s) 0.0074 | Loss 0.9803 | Accuracy 0.7560 | ETputs(KTEPS) 1785.97
# Epoch 00057 | Time(s) 0.0074 | Loss 0.9752 | Accuracy 0.7520 | ETputs(KTEPS) 1787.71
# Epoch 00058 | Time(s) 0.0074 | Loss 0.9693 | Accuracy 0.7540 | ETputs(KTEPS) 1791.39
# Epoch 00059 | Time(s) 0.0074 | Loss 0.9553 | Accuracy 0.7540 | ETputs(KTEPS) 1794.33
# Epoch 00060 | Time(s) 0.0074 | Loss 0.9318 | Accuracy 0.7520 | ETputs(KTEPS) 1796.48
# Epoch 00061 | Time(s) 0.0074 | Loss 0.9460 | Accuracy 0.7580 | ETputs(KTEPS) 1800.11
# Epoch 00062 | Time(s) 0.0074 | Loss 0.9128 | Accuracy 0.7620 | ETputs(KTEPS) 1803.92
# Epoch 00063 | Time(s) 0.0073 | Loss 0.9249 | Accuracy 0.7600 | ETputs(KTEPS) 1806.73
# Epoch 00064 | Time(s) 0.0073 | Loss 0.9232 | Accuracy 0.7580 | ETputs(KTEPS) 1810.50
# Epoch 00065 | Time(s) 0.0073 | Loss 0.8648 | Accuracy 0.7600 | ETputs(KTEPS) 1813.25
# Epoch 00066 | Time(s) 0.0073 | Loss 0.8670 | Accuracy 0.7560 | ETputs(KTEPS) 1812.92
# Epoch 00067 | Time(s) 0.0073 | Loss 0.8344 | Accuracy 0.7620 | ETputs(KTEPS) 1816.01
# Epoch 00068 | Time(s) 0.0073 | Loss 0.8162 | Accuracy 0.7600 | ETputs(KTEPS) 1814.25
# Epoch 00069 | Time(s) 0.0073 | Loss 0.8154 | Accuracy 0.7560 | ETputs(KTEPS) 1816.00
# Epoch 00070 | Time(s) 0.0073 | Loss 0.8293 | Accuracy 0.7560 | ETputs(KTEPS) 1817.98
# Epoch 00071 | Time(s) 0.0073 | Loss 0.7764 | Accuracy 0.7620 | ETputs(KTEPS) 1815.91
# Epoch 00072 | Time(s) 0.0073 | Loss 0.7838 | Accuracy 0.7600 | ETputs(KTEPS) 1812.16
# Epoch 00073 | Time(s) 0.0073 | Loss 0.7946 | Accuracy 0.7640 | ETputs(KTEPS) 1810.75
# Epoch 00074 | Time(s) 0.0073 | Loss 0.7789 | Accuracy 0.7600 | ETputs(KTEPS) 1811.97
# Epoch 00075 | Time(s) 0.0073 | Loss 0.7426 | Accuracy 0.7580 | ETputs(KTEPS) 1814.09
# Epoch 00076 | Time(s) 0.0073 | Loss 0.7262 | Accuracy 0.7600 | ETputs(KTEPS) 1813.39
# Epoch 00077 | Time(s) 0.0073 | Loss 0.7243 | Accuracy 0.7600 | ETputs(KTEPS) 1815.35
# Epoch 00078 | Time(s) 0.0073 | Loss 0.7149 | Accuracy 0.7600 | ETputs(KTEPS) 1817.97
# Epoch 00079 | Time(s) 0.0073 | Loss 0.6882 | Accuracy 0.7620 | ETputs(KTEPS) 1819.15
# Epoch 00080 | Time(s) 0.0073 | Loss 0.6967 | Accuracy 0.7620 | ETputs(KTEPS) 1822.61
# Epoch 00081 | Time(s) 0.0073 | Loss 0.7168 | Accuracy 0.7620 | ETputs(KTEPS) 1826.25
# Epoch 00082 | Time(s) 0.0072 | Loss 0.6935 | Accuracy 0.7600 | ETputs(KTEPS) 1829.79
# Epoch 00083 | Time(s) 0.0072 | Loss 0.6369 | Accuracy 0.7620 | ETputs(KTEPS) 1833.03
# Epoch 00084 | Time(s) 0.0072 | Loss 0.6372 | Accuracy 0.7560 | ETputs(KTEPS) 1837.08
# Epoch 00085 | Time(s) 0.0072 | Loss 0.6960 | Accuracy 0.7560 | ETputs(KTEPS) 1838.43
# Epoch 00086 | Time(s) 0.0072 | Loss 0.6028 | Accuracy 0.7560 | ETputs(KTEPS) 1839.14
# Epoch 00087 | Time(s) 0.0072 | Loss 0.6665 | Accuracy 0.7600 | ETputs(KTEPS) 1841.59
# Epoch 00088 | Time(s) 0.0072 | Loss 0.6251 | Accuracy 0.7620 | ETputs(KTEPS) 1840.53
# Epoch 00089 | Time(s) 0.0072 | Loss 0.6123 | Accuracy 0.7600 | ETputs(KTEPS) 1837.04
# Epoch 00090 | Time(s) 0.0072 | Loss 0.6246 | Accuracy 0.7680 | ETputs(KTEPS) 1834.99
# Epoch 00091 | Time(s) 0.0072 | Loss 0.6337 | Accuracy 0.7700 | ETputs(KTEPS) 1837.15
# Epoch 00092 | Time(s) 0.0072 | Loss 0.5937 | Accuracy 0.7720 | ETputs(KTEPS) 1837.34
# Epoch 00093 | Time(s) 0.0072 | Loss 0.6365 | Accuracy 0.7720 | ETputs(KTEPS) 1839.07
# Epoch 00094 | Time(s) 0.0072 | Loss 0.6160 | Accuracy 0.7720 | ETputs(KTEPS) 1840.57
# Epoch 00095 | Time(s) 0.0072 | Loss 0.5808 | Accuracy 0.7720 | ETputs(KTEPS) 1842.86
# Epoch 00096 | Time(s) 0.0072 | Loss 0.5842 | Accuracy 0.7760 | ETputs(KTEPS) 1844.65
# Epoch 00097 | Time(s) 0.0072 | Loss 0.5886 | Accuracy 0.7740 | ETputs(KTEPS) 1847.58
# Epoch 00098 | Time(s) 0.0072 | Loss 0.5866 | Accuracy 0.7680 | ETputs(KTEPS) 1850.54
# Epoch 00099 | Time(s) 0.0072 | Loss 0.5430 | Accuracy 0.7720 | ETputs(KTEPS) 1852.89
# Epoch 00100 | Time(s) 0.0071 | Loss 0.5806 | Accuracy 0.7720 | ETputs(KTEPS) 1855.18
# Epoch 00101 | Time(s) 0.0071 | Loss 0.5857 | Accuracy 0.7680 | ETputs(KTEPS) 1856.35
# Epoch 00102 | Time(s) 0.0071 | Loss 0.5429 | Accuracy 0.7640 | ETputs(KTEPS) 1858.43
# Epoch 00103 | Time(s) 0.0071 | Loss 0.5722 | Accuracy 0.7640 | ETputs(KTEPS) 1859.51
# Epoch 00104 | Time(s) 0.0071 | Loss 0.5295 | Accuracy 0.7700 | ETputs(KTEPS) 1861.65
# Epoch 00105 | Time(s) 0.0071 | Loss 0.5430 | Accuracy 0.7720 | ETputs(KTEPS) 1862.15
# Epoch 00106 | Time(s) 0.0071 | Loss 0.5184 | Accuracy 0.7760 | ETputs(KTEPS) 1863.31
# Epoch 00107 | Time(s) 0.0071 | Loss 0.5297 | Accuracy 0.7760 | ETputs(KTEPS) 1864.36
# Epoch 00108 | Time(s) 0.0071 | Loss 0.4967 | Accuracy 0.7820 | ETputs(KTEPS) 1864.39
# Epoch 00109 | Time(s) 0.0071 | Loss 0.5239 | Accuracy 0.7820 | ETputs(KTEPS) 1862.56
# Epoch 00110 | Time(s) 0.0071 | Loss 0.5214 | Accuracy 0.7820 | ETputs(KTEPS) 1863.76
# Epoch 00111 | Time(s) 0.0071 | Loss 0.5661 | Accuracy 0.7820 | ETputs(KTEPS) 1864.59
# Epoch 00112 | Time(s) 0.0071 | Loss 0.5363 | Accuracy 0.7800 | ETputs(KTEPS) 1866.37
# Epoch 00113 | Time(s) 0.0071 | Loss 0.4960 | Accuracy 0.7800 | ETputs(KTEPS) 1868.39
# Epoch 00114 | Time(s) 0.0071 | Loss 0.5082 | Accuracy 0.7820 | ETputs(KTEPS) 1869.10
# Epoch 00115 | Time(s) 0.0071 | Loss 0.5310 | Accuracy 0.7760 | ETputs(KTEPS) 1871.21
# Epoch 00116 | Time(s) 0.0071 | Loss 0.5014 | Accuracy 0.7740 | ETputs(KTEPS) 1873.52
# Epoch 00117 | Time(s) 0.0071 | Loss 0.4683 | Accuracy 0.7700 | ETputs(KTEPS) 1875.79
# Epoch 00118 | Time(s) 0.0071 | Loss 0.4828 | Accuracy 0.7720 | ETputs(KTEPS) 1877.37
# Epoch 00119 | Time(s) 0.0071 | Loss 0.4910 | Accuracy 0.7720 | ETputs(KTEPS) 1877.61
# Epoch 00120 | Time(s) 0.0071 | Loss 0.4757 | Accuracy 0.7820 | ETputs(KTEPS) 1878.41
# Epoch 00121 | Time(s) 0.0071 | Loss 0.4591 | Accuracy 0.7800 | ETputs(KTEPS) 1879.00
# Epoch 00122 | Time(s) 0.0071 | Loss 0.4879 | Accuracy 0.7780 | ETputs(KTEPS) 1881.08
# Epoch 00123 | Time(s) 0.0070 | Loss 0.4734 | Accuracy 0.7780 | ETputs(KTEPS) 1881.48
# Epoch 00124 | Time(s) 0.0070 | Loss 0.4672 | Accuracy 0.7780 | ETputs(KTEPS) 1882.41
# Epoch 00125 | Time(s) 0.0070 | Loss 0.5139 | Accuracy 0.7780 | ETputs(KTEPS) 1882.46
# Epoch 00126 | Time(s) 0.0070 | Loss 0.4533 | Accuracy 0.7780 | ETputs(KTEPS) 1882.01
# Epoch 00127 | Time(s) 0.0071 | Loss 0.4470 | Accuracy 0.7800 | ETputs(KTEPS) 1880.20
# Epoch 00128 | Time(s) 0.0070 | Loss 0.4857 | Accuracy 0.7800 | ETputs(KTEPS) 1881.87
# Epoch 00129 | Time(s) 0.0070 | Loss 0.4509 | Accuracy 0.7800 | ETputs(KTEPS) 1882.04
# Epoch 00130 | Time(s) 0.0070 | Loss 0.4447 | Accuracy 0.7820 | ETputs(KTEPS) 1883.56
# Epoch 00131 | Time(s) 0.0070 | Loss 0.4480 | Accuracy 0.7820 | ETputs(KTEPS) 1885.13
# Epoch 00132 | Time(s) 0.0070 | Loss 0.4419 | Accuracy 0.7820 | ETputs(KTEPS) 1886.81
# Epoch 00133 | Time(s) 0.0070 | Loss 0.4149 | Accuracy 0.7820 | ETputs(KTEPS) 1888.37
# Epoch 00134 | Time(s) 0.0070 | Loss 0.4091 | Accuracy 0.7800 | ETputs(KTEPS) 1890.35
# Epoch 00135 | Time(s) 0.0070 | Loss 0.4900 | Accuracy 0.7800 | ETputs(KTEPS) 1892.27
# Epoch 00136 | Time(s) 0.0070 | Loss 0.3896 | Accuracy 0.7800 | ETputs(KTEPS) 1893.79
# Epoch 00137 | Time(s) 0.0070 | Loss 0.4203 | Accuracy 0.7780 | ETputs(KTEPS) 1895.41
# Epoch 00138 | Time(s) 0.0070 | Loss 0.4470 | Accuracy 0.7760 | ETputs(KTEPS) 1896.49
# Epoch 00139 | Time(s) 0.0070 | Loss 0.4063 | Accuracy 0.7760 | ETputs(KTEPS) 1897.54
# Epoch 00140 | Time(s) 0.0070 | Loss 0.4379 | Accuracy 0.7760 | ETputs(KTEPS) 1899.38
# Epoch 00141 | Time(s) 0.0070 | Loss 0.3962 | Accuracy 0.7740 | ETputs(KTEPS) 1899.52
# Epoch 00142 | Time(s) 0.0070 | Loss 0.4594 | Accuracy 0.7740 | ETputs(KTEPS) 1900.41
# Epoch 00143 | Time(s) 0.0070 | Loss 0.4201 | Accuracy 0.7760 | ETputs(KTEPS) 1900.42
# Epoch 00144 | Time(s) 0.0070 | Loss 0.4024 | Accuracy 0.7820 | ETputs(KTEPS) 1899.90
# Epoch 00145 | Time(s) 0.0070 | Loss 0.3893 | Accuracy 0.7840 | ETputs(KTEPS) 1899.49
# Epoch 00146 | Time(s) 0.0070 | Loss 0.4341 | Accuracy 0.7840 | ETputs(KTEPS) 1900.55
# Epoch 00147 | Time(s) 0.0070 | Loss 0.3995 | Accuracy 0.7800 | ETputs(KTEPS) 1900.34
# Epoch 00148 | Time(s) 0.0070 | Loss 0.3946 | Accuracy 0.7800 | ETputs(KTEPS) 1901.65
# Epoch 00149 | Time(s) 0.0070 | Loss 0.3724 | Accuracy 0.7820 | ETputs(KTEPS) 1903.72
# Epoch 00150 | Time(s) 0.0070 | Loss 0.4009 | Accuracy 0.7780 | ETputs(KTEPS) 1904.28
# Epoch 00151 | Time(s) 0.0070 | Loss 0.3920 | Accuracy 0.7780 | ETputs(KTEPS) 1905.66
# Epoch 00152 | Time(s) 0.0070 | Loss 0.4039 | Accuracy 0.7780 | ETputs(KTEPS) 1907.33
# Epoch 00153 | Time(s) 0.0069 | Loss 0.4211 | Accuracy 0.7780 | ETputs(KTEPS) 1908.79
# Epoch 00154 | Time(s) 0.0069 | Loss 0.4455 | Accuracy 0.7780 | ETputs(KTEPS) 1910.37
# Epoch 00155 | Time(s) 0.0069 | Loss 0.4095 | Accuracy 0.7760 | ETputs(KTEPS) 1911.27
# Epoch 00156 | Time(s) 0.0069 | Loss 0.4119 | Accuracy 0.7760 | ETputs(KTEPS) 1911.82
# Epoch 00157 | Time(s) 0.0069 | Loss 0.3794 | Accuracy 0.7760 | ETputs(KTEPS) 1912.86
# Epoch 00158 | Time(s) 0.0069 | Loss 0.3848 | Accuracy 0.7820 | ETputs(KTEPS) 1914.35
# Epoch 00159 | Time(s) 0.0069 | Loss 0.3834 | Accuracy 0.7820 | ETputs(KTEPS) 1915.03
# Epoch 00160 | Time(s) 0.0069 | Loss 0.3981 | Accuracy 0.7820 | ETputs(KTEPS) 1914.86
# Epoch 00161 | Time(s) 0.0069 | Loss 0.3842 | Accuracy 0.7820 | ETputs(KTEPS) 1916.00
# Epoch 00162 | Time(s) 0.0069 | Loss 0.3931 | Accuracy 0.7820 | ETputs(KTEPS) 1916.68
# Epoch 00163 | Time(s) 0.0069 | Loss 0.4012 | Accuracy 0.7820 | ETputs(KTEPS) 1916.77
# Epoch 00164 | Time(s) 0.0069 | Loss 0.3831 | Accuracy 0.7820 | ETputs(KTEPS) 1915.10
# Epoch 00165 | Time(s) 0.0069 | Loss 0.3948 | Accuracy 0.7820 | ETputs(KTEPS) 1914.31
# Epoch 00166 | Time(s) 0.0069 | Loss 0.3900 | Accuracy 0.7840 | ETputs(KTEPS) 1914.22
# Epoch 00167 | Time(s) 0.0069 | Loss 0.3717 | Accuracy 0.7780 | ETputs(KTEPS) 1915.77
# Epoch 00168 | Time(s) 0.0069 | Loss 0.3719 | Accuracy 0.7760 | ETputs(KTEPS) 1916.55
# Epoch 00169 | Time(s) 0.0069 | Loss 0.3175 | Accuracy 0.7760 | ETputs(KTEPS) 1917.78
# Epoch 00170 | Time(s) 0.0069 | Loss 0.3514 | Accuracy 0.7820 | ETputs(KTEPS) 1919.27
# Epoch 00171 | Time(s) 0.0069 | Loss 0.3257 | Accuracy 0.7800 | ETputs(KTEPS) 1920.67
# Epoch 00172 | Time(s) 0.0069 | Loss 0.3577 | Accuracy 0.7840 | ETputs(KTEPS) 1922.06
# Epoch 00173 | Time(s) 0.0069 | Loss 0.3874 | Accuracy 0.7800 | ETputs(KTEPS) 1923.30
# Epoch 00174 | Time(s) 0.0069 | Loss 0.3732 | Accuracy 0.7840 | ETputs(KTEPS) 1923.60
# Epoch 00175 | Time(s) 0.0069 | Loss 0.3522 | Accuracy 0.7820 | ETputs(KTEPS) 1925.11
# Epoch 00176 | Time(s) 0.0069 | Loss 0.3612 | Accuracy 0.7820 | ETputs(KTEPS) 1925.59
# Epoch 00177 | Time(s) 0.0069 | Loss 0.3373 | Accuracy 0.7840 | ETputs(KTEPS) 1925.57
# Epoch 00178 | Time(s) 0.0069 | Loss 0.3465 | Accuracy 0.7860 | ETputs(KTEPS) 1926.69
# Epoch 00179 | Time(s) 0.0069 | Loss 0.3685 | Accuracy 0.7840 | ETputs(KTEPS) 1926.61
# Epoch 00180 | Time(s) 0.0069 | Loss 0.3577 | Accuracy 0.7860 | ETputs(KTEPS) 1927.49
# Epoch 00181 | Time(s) 0.0069 | Loss 0.3593 | Accuracy 0.7760 | ETputs(KTEPS) 1927.45
# Epoch 00182 | Time(s) 0.0069 | Loss 0.3275 | Accuracy 0.7800 | ETputs(KTEPS) 1928.02
# Epoch 00183 | Time(s) 0.0069 | Loss 0.3827 | Accuracy 0.7800 | ETputs(KTEPS) 1926.08
# Epoch 00184 | Time(s) 0.0069 | Loss 0.3437 | Accuracy 0.7800 | ETputs(KTEPS) 1925.42
# Epoch 00185 | Time(s) 0.0069 | Loss 0.3769 | Accuracy 0.7800 | ETputs(KTEPS) 1924.64
# Epoch 00186 | Time(s) 0.0069 | Loss 0.3101 | Accuracy 0.7820 | ETputs(KTEPS) 1923.07
# Epoch 00187 | Time(s) 0.0069 | Loss 0.3612 | Accuracy 0.7800 | ETputs(KTEPS) 1917.57
# Epoch 00188 | Time(s) 0.0069 | Loss 0.3314 | Accuracy 0.7820 | ETputs(KTEPS) 1914.21
# Epoch 00189 | Time(s) 0.0069 | Loss 0.3220 | Accuracy 0.7880 | ETputs(KTEPS) 1914.02
# Epoch 00190 | Time(s) 0.0069 | Loss 0.3550 | Accuracy 0.7880 | ETputs(KTEPS) 1913.96
# Epoch 00191 | Time(s) 0.0069 | Loss 0.3496 | Accuracy 0.7860 | ETputs(KTEPS) 1913.60
# Epoch 00192 | Time(s) 0.0069 | Loss 0.3709 | Accuracy 0.7820 | ETputs(KTEPS) 1913.24
# Epoch 00193 | Time(s) 0.0069 | Loss 0.3215 | Accuracy 0.7780 | ETputs(KTEPS) 1913.53
# Epoch 00194 | Time(s) 0.0069 | Loss 0.3333 | Accuracy 0.7840 | ETputs(KTEPS) 1914.52
# Epoch 00195 | Time(s) 0.0069 | Loss 0.3351 | Accuracy 0.7840 | ETputs(KTEPS) 1915.01
# Epoch 00196 | Time(s) 0.0069 | Loss 0.3491 | Accuracy 0.7820 | ETputs(KTEPS) 1915.12
# Epoch 00197 | Time(s) 0.0069 | Loss 0.3429 | Accuracy 0.7840 | ETputs(KTEPS) 1916.22
# Epoch 00198 | Time(s) 0.0069 | Loss 0.3263 | Accuracy 0.7800 | ETputs(KTEPS) 1916.68
# Epoch 00199 | Time(s) 0.0069 | Loss 0.3189 | Accuracy 0.7800 | ETputs(KTEPS) 1916.42
# Epoch 00200 | Time(s) 0.0069 | Loss 0.3191 | Accuracy 0.7860 | ETputs(KTEPS) 1916.58
# Epoch 00201 | Time(s) 0.0069 | Loss 0.3379 | Accuracy 0.7920 | ETputs(KTEPS) 1915.59
# Epoch 00202 | Time(s) 0.0069 | Loss 0.3361 | Accuracy 0.7840 | ETputs(KTEPS) 1915.86
# Epoch 00203 | Time(s) 0.0069 | Loss 0.3682 | Accuracy 0.7800 | ETputs(KTEPS) 1917.06
# Epoch 00204 | Time(s) 0.0069 | Loss 0.3007 | Accuracy 0.7800 | ETputs(KTEPS) 1917.44
# Epoch 00205 | Time(s) 0.0069 | Loss 0.3397 | Accuracy 0.7820 | ETputs(KTEPS) 1918.68
# Epoch 00206 | Time(s) 0.0069 | Loss 0.3242 | Accuracy 0.7820 | ETputs(KTEPS) 1919.82
# Epoch 00207 | Time(s) 0.0069 | Loss 0.3033 | Accuracy 0.7820 | ETputs(KTEPS) 1920.41
# Epoch 00208 | Time(s) 0.0069 | Loss 0.3017 | Accuracy 0.7820 | ETputs(KTEPS) 1921.20
# Epoch 00209 | Time(s) 0.0069 | Loss 0.3215 | Accuracy 0.7860 | ETputs(KTEPS) 1922.44
# Epoch 00210 | Time(s) 0.0069 | Loss 0.3419 | Accuracy 0.7860 | ETputs(KTEPS) 1923.02
# Epoch 00211 | Time(s) 0.0069 | Loss 0.2977 | Accuracy 0.7860 | ETputs(KTEPS) 1924.25
# Epoch 00212 | Time(s) 0.0069 | Loss 0.3165 | Accuracy 0.7880 | ETputs(KTEPS) 1924.49
# Epoch 00213 | Time(s) 0.0069 | Loss 0.3046 | Accuracy 0.7820 | ETputs(KTEPS) 1925.14
# Epoch 00214 | Time(s) 0.0069 | Loss 0.3100 | Accuracy 0.7780 | ETputs(KTEPS) 1926.31
# Epoch 00215 | Time(s) 0.0069 | Loss 0.3283 | Accuracy 0.7800 | ETputs(KTEPS) 1926.34
# Epoch 00216 | Time(s) 0.0069 | Loss 0.3426 | Accuracy 0.7800 | ETputs(KTEPS) 1926.80
# Epoch 00217 | Time(s) 0.0069 | Loss 0.3002 | Accuracy 0.7820 | ETputs(KTEPS) 1926.77
# Epoch 00218 | Time(s) 0.0069 | Loss 0.3174 | Accuracy 0.7820 | ETputs(KTEPS) 1925.83
# Epoch 00219 | Time(s) 0.0069 | Loss 0.3146 | Accuracy 0.7860 | ETputs(KTEPS) 1924.25
# Epoch 00220 | Time(s) 0.0069 | Loss 0.2974 | Accuracy 0.7860 | ETputs(KTEPS) 1922.94
# Epoch 00221 | Time(s) 0.0069 | Loss 0.3161 | Accuracy 0.7860 | ETputs(KTEPS) 1922.17
# Epoch 00222 | Time(s) 0.0069 | Loss 0.3155 | Accuracy 0.7840 | ETputs(KTEPS) 1922.48
# Epoch 00223 | Time(s) 0.0069 | Loss 0.3310 | Accuracy 0.7820 | ETputs(KTEPS) 1922.57
# Epoch 00224 | Time(s) 0.0069 | Loss 0.3152 | Accuracy 0.7780 | ETputs(KTEPS) 1922.47
# Epoch 00225 | Time(s) 0.0069 | Loss 0.2995 | Accuracy 0.7780 | ETputs(KTEPS) 1923.02
# Epoch 00226 | Time(s) 0.0069 | Loss 0.3216 | Accuracy 0.7780 | ETputs(KTEPS) 1924.09
# Epoch 00227 | Time(s) 0.0069 | Loss 0.2758 | Accuracy 0.7800 | ETputs(KTEPS) 1925.25
# Epoch 00228 | Time(s) 0.0069 | Loss 0.2830 | Accuracy 0.7800 | ETputs(KTEPS) 1925.87
# Epoch 00229 | Time(s) 0.0069 | Loss 0.3079 | Accuracy 0.7800 | ETputs(KTEPS) 1926.31
# Epoch 00230 | Time(s) 0.0069 | Loss 0.2773 | Accuracy 0.7760 | ETputs(KTEPS) 1926.34
# Epoch 00231 | Time(s) 0.0069 | Loss 0.2593 | Accuracy 0.7780 | ETputs(KTEPS) 1927.18
# Epoch 00232 | Time(s) 0.0069 | Loss 0.3346 | Accuracy 0.7800 | ETputs(KTEPS) 1928.08
# Epoch 00233 | Time(s) 0.0069 | Loss 0.3141 | Accuracy 0.7820 | ETputs(KTEPS) 1928.51
# Epoch 00234 | Time(s) 0.0069 | Loss 0.2783 | Accuracy 0.7820 | ETputs(KTEPS) 1928.92
# Epoch 00235 | Time(s) 0.0069 | Loss 0.2895 | Accuracy 0.7840 | ETputs(KTEPS) 1929.34
# Epoch 00236 | Time(s) 0.0069 | Loss 0.2785 | Accuracy 0.7820 | ETputs(KTEPS) 1928.67
# Epoch 00237 | Time(s) 0.0069 | Loss 0.2855 | Accuracy 0.7840 | ETputs(KTEPS) 1927.79
# Epoch 00238 | Time(s) 0.0069 | Loss 0.2994 | Accuracy 0.7860 | ETputs(KTEPS) 1927.23
# Epoch 00239 | Time(s) 0.0069 | Loss 0.2898 | Accuracy 0.7840 | ETputs(KTEPS) 1927.64
# Epoch 00240 | Time(s) 0.0069 | Loss 0.2828 | Accuracy 0.7800 | ETputs(KTEPS) 1928.67
# Epoch 00241 | Time(s) 0.0069 | Loss 0.2962 | Accuracy 0.7800 | ETputs(KTEPS) 1929.66
# Epoch 00242 | Time(s) 0.0069 | Loss 0.2765 | Accuracy 0.7800 | ETputs(KTEPS) 1930.15
# Epoch 00243 | Time(s) 0.0069 | Loss 0.2784 | Accuracy 0.7800 | ETputs(KTEPS) 1931.07
# Epoch 00244 | Time(s) 0.0069 | Loss 0.2754 | Accuracy 0.7800 | ETputs(KTEPS) 1931.97
# Epoch 00245 | Time(s) 0.0069 | Loss 0.3095 | Accuracy 0.7820 | ETputs(KTEPS) 1932.89
# Epoch 00246 | Time(s) 0.0069 | Loss 0.3110 | Accuracy 0.7820 | ETputs(KTEPS) 1933.66
# Epoch 00247 | Time(s) 0.0069 | Loss 0.3001 | Accuracy 0.7800 | ETputs(KTEPS) 1933.16
# Epoch 00248 | Time(s) 0.0069 | Loss 0.3080 | Accuracy 0.7800 | ETputs(KTEPS) 1932.79
# Epoch 00249 | Time(s) 0.0069 | Loss 0.3392 | Accuracy 0.7800 | ETputs(KTEPS) 1933.82
# Epoch 00250 | Time(s) 0.0069 | Loss 0.2742 | Accuracy 0.7800 | ETputs(KTEPS) 1934.74
# Epoch 00251 | Time(s) 0.0069 | Loss 0.2583 | Accuracy 0.7800 | ETputs(KTEPS) 1935.21
# Epoch 00252 | Time(s) 0.0069 | Loss 0.3011 | Accuracy 0.7800 | ETputs(KTEPS) 1934.90
# Epoch 00253 | Time(s) 0.0069 | Loss 0.2698 | Accuracy 0.7800 | ETputs(KTEPS) 1934.70
# Epoch 00254 | Time(s) 0.0069 | Loss 0.2994 | Accuracy 0.7800 | ETputs(KTEPS) 1935.01
# Epoch 00255 | Time(s) 0.0069 | Loss 0.2695 | Accuracy 0.7820 | ETputs(KTEPS) 1935.11
# Epoch 00256 | Time(s) 0.0069 | Loss 0.2865 | Accuracy 0.7800 | ETputs(KTEPS) 1934.39
# Epoch 00257 | Time(s) 0.0069 | Loss 0.2687 | Accuracy 0.7860 | ETputs(KTEPS) 1933.75
# Epoch 00258 | Time(s) 0.0069 | Loss 0.2581 | Accuracy 0.7840 | ETputs(KTEPS) 1933.19
# Epoch 00259 | Time(s) 0.0069 | Loss 0.3040 | Accuracy 0.7840 | ETputs(KTEPS) 1932.95
# Epoch 00260 | Time(s) 0.0069 | Loss 0.2739 | Accuracy 0.7820 | ETputs(KTEPS) 1932.11
# Epoch 00261 | Time(s) 0.0069 | Loss 0.2977 | Accuracy 0.7840 | ETputs(KTEPS) 1932.14
# Epoch 00262 | Time(s) 0.0069 | Loss 0.2905 | Accuracy 0.7820 | ETputs(KTEPS) 1932.29
# Epoch 00263 | Time(s) 0.0069 | Loss 0.2733 | Accuracy 0.7820 | ETputs(KTEPS) 1932.36
# Epoch 00264 | Time(s) 0.0069 | Loss 0.2666 | Accuracy 0.7820 | ETputs(KTEPS) 1932.12
# Epoch 00265 | Time(s) 0.0069 | Loss 0.3042 | Accuracy 0.7820 | ETputs(KTEPS) 1931.49
# Epoch 00266 | Time(s) 0.0069 | Loss 0.2616 | Accuracy 0.7840 | ETputs(KTEPS) 1931.17
# Epoch 00267 | Time(s) 0.0069 | Loss 0.2640 | Accuracy 0.7840 | ETputs(KTEPS) 1931.17
# Epoch 00268 | Time(s) 0.0069 | Loss 0.2754 | Accuracy 0.7820 | ETputs(KTEPS) 1931.46
# Epoch 00269 | Time(s) 0.0069 | Loss 0.2776 | Accuracy 0.7820 | ETputs(KTEPS) 1931.53
# Epoch 00270 | Time(s) 0.0069 | Loss 0.2989 | Accuracy 0.7820 | ETputs(KTEPS) 1930.64
# Epoch 00271 | Time(s) 0.0069 | Loss 0.2888 | Accuracy 0.7880 | ETputs(KTEPS) 1930.23
# Epoch 00272 | Time(s) 0.0069 | Loss 0.2511 | Accuracy 0.7880 | ETputs(KTEPS) 1929.40
# Epoch 00273 | Time(s) 0.0069 | Loss 0.2787 | Accuracy 0.7880 | ETputs(KTEPS) 1928.41
# Epoch 00274 | Time(s) 0.0069 | Loss 0.3063 | Accuracy 0.7860 | ETputs(KTEPS) 1926.68
# Epoch 00275 | Time(s) 0.0069 | Loss 0.2808 | Accuracy 0.7860 | ETputs(KTEPS) 1925.90
# Epoch 00276 | Time(s) 0.0069 | Loss 0.2965 | Accuracy 0.7880 | ETputs(KTEPS) 1926.22
# Epoch 00277 | Time(s) 0.0069 | Loss 0.2775 | Accuracy 0.7860 | ETputs(KTEPS) 1926.23
# Epoch 00278 | Time(s) 0.0069 | Loss 0.2475 | Accuracy 0.7880 | ETputs(KTEPS) 1926.05
# Epoch 00279 | Time(s) 0.0069 | Loss 0.2527 | Accuracy 0.7880 | ETputs(KTEPS) 1926.21
# Epoch 00280 | Time(s) 0.0069 | Loss 0.2514 | Accuracy 0.7840 | ETputs(KTEPS) 1926.42
# Epoch 00281 | Time(s) 0.0069 | Loss 0.2739 | Accuracy 0.7860 | ETputs(KTEPS) 1926.09
# Epoch 00282 | Time(s) 0.0069 | Loss 0.2486 | Accuracy 0.7820 | ETputs(KTEPS) 1926.50
# Epoch 00283 | Time(s) 0.0069 | Loss 0.2692 | Accuracy 0.7840 | ETputs(KTEPS) 1926.53
# Epoch 00284 | Time(s) 0.0069 | Loss 0.2785 | Accuracy 0.7860 | ETputs(KTEPS) 1927.13
# Epoch 00285 | Time(s) 0.0069 | Loss 0.2697 | Accuracy 0.7820 | ETputs(KTEPS) 1927.88
# Epoch 00286 | Time(s) 0.0069 | Loss 0.2320 | Accuracy 0.7860 | ETputs(KTEPS) 1928.66
# Epoch 00287 | Time(s) 0.0069 | Loss 0.2867 | Accuracy 0.7860 | ETputs(KTEPS) 1929.44
# Epoch 00288 | Time(s) 0.0069 | Loss 0.2702 | Accuracy 0.7860 | ETputs(KTEPS) 1929.76
# Epoch 00289 | Time(s) 0.0069 | Loss 0.2372 | Accuracy 0.7860 | ETputs(KTEPS) 1930.40
# Epoch 00290 | Time(s) 0.0069 | Loss 0.2386 | Accuracy 0.7820 | ETputs(KTEPS) 1930.57
# Epoch 00291 | Time(s) 0.0069 | Loss 0.2497 | Accuracy 0.7800 | ETputs(KTEPS) 1930.27
# Epoch 00292 | Time(s) 0.0069 | Loss 0.2456 | Accuracy 0.7840 | ETputs(KTEPS) 1929.35
# Epoch 00293 | Time(s) 0.0069 | Loss 0.2648 | Accuracy 0.7860 | ETputs(KTEPS) 1928.13
# Epoch 00294 | Time(s) 0.0069 | Loss 0.2635 | Accuracy 0.7820 | ETputs(KTEPS) 1927.62
# Epoch 00295 | Time(s) 0.0069 | Loss 0.2552 | Accuracy 0.7860 | ETputs(KTEPS) 1927.40
# Epoch 00296 | Time(s) 0.0069 | Loss 0.2657 | Accuracy 0.7860 | ETputs(KTEPS) 1927.45
# Epoch 00297 | Time(s) 0.0069 | Loss 0.2555 | Accuracy 0.7840 | ETputs(KTEPS) 1927.57
# Epoch 00298 | Time(s) 0.0069 | Loss 0.2724 | Accuracy 0.7880 | ETputs(KTEPS) 1927.40
# Epoch 00299 | Time(s) 0.0069 | Loss 0.2437 | Accuracy 0.7900 | ETputs(KTEPS) 1927.48
# Epoch 00300 | Time(s) 0.0069 | Loss 0.2309 | Accuracy 0.7900 | ETputs(KTEPS) 1927.55
# Epoch 00301 | Time(s) 0.0069 | Loss 0.3091 | Accuracy 0.7900 | ETputs(KTEPS) 1927.38
# Epoch 00302 | Time(s) 0.0069 | Loss 0.2780 | Accuracy 0.7920 | ETputs(KTEPS) 1927.23
# Epoch 00303 | Time(s) 0.0069 | Loss 0.2551 | Accuracy 0.7880 | ETputs(KTEPS) 1927.31
# Epoch 00304 | Time(s) 0.0069 | Loss 0.2742 | Accuracy 0.7860 | ETputs(KTEPS) 1927.03
# Epoch 00305 | Time(s) 0.0069 | Loss 0.2670 | Accuracy 0.7860 | ETputs(KTEPS) 1926.84
# Epoch 00306 | Time(s) 0.0069 | Loss 0.2471 | Accuracy 0.7900 | ETputs(KTEPS) 1926.36
# Epoch 00307 | Time(s) 0.0069 | Loss 0.2218 | Accuracy 0.7860 | ETputs(KTEPS) 1925.84
# Epoch 00308 | Time(s) 0.0069 | Loss 0.2365 | Accuracy 0.7880 | ETputs(KTEPS) 1925.16
# Epoch 00309 | Time(s) 0.0069 | Loss 0.2542 | Accuracy 0.7900 | ETputs(KTEPS) 1924.17
# Epoch 00310 | Time(s) 0.0069 | Loss 0.2604 | Accuracy 0.7900 | ETputs(KTEPS) 1924.00
# Epoch 00311 | Time(s) 0.0069 | Loss 0.2533 | Accuracy 0.7880 | ETputs(KTEPS) 1923.62
# Epoch 00312 | Time(s) 0.0069 | Loss 0.2682 | Accuracy 0.7900 | ETputs(KTEPS) 1922.61
# Epoch 00313 | Time(s) 0.0069 | Loss 0.2679 | Accuracy 0.7920 | ETputs(KTEPS) 1923.03
# Epoch 00314 | Time(s) 0.0069 | Loss 0.2174 | Accuracy 0.7880 | ETputs(KTEPS) 1923.67
# Epoch 00315 | Time(s) 0.0069 | Loss 0.2020 | Accuracy 0.7860 | ETputs(KTEPS) 1924.05
# Epoch 00316 | Time(s) 0.0069 | Loss 0.2304 | Accuracy 0.7840 | ETputs(KTEPS) 1924.80
# Epoch 00317 | Time(s) 0.0069 | Loss 0.2445 | Accuracy 0.7840 | ETputs(KTEPS) 1925.30
# Epoch 00318 | Time(s) 0.0069 | Loss 0.2813 | Accuracy 0.7900 | ETputs(KTEPS) 1925.52
# Epoch 00319 | Time(s) 0.0069 | Loss 0.2419 | Accuracy 0.7880 | ETputs(KTEPS) 1925.91
# Epoch 00320 | Time(s) 0.0069 | Loss 0.2603 | Accuracy 0.7880 | ETputs(KTEPS) 1925.60
# Epoch 00321 | Time(s) 0.0069 | Loss 0.2409 | Accuracy 0.7860 | ETputs(KTEPS) 1925.44
# Epoch 00322 | Time(s) 0.0069 | Loss 0.2509 | Accuracy 0.7880 | ETputs(KTEPS) 1925.55
# Epoch 00323 | Time(s) 0.0069 | Loss 0.2952 | Accuracy 0.7880 | ETputs(KTEPS) 1925.64
# Epoch 00324 | Time(s) 0.0069 | Loss 0.2426 | Accuracy 0.7880 | ETputs(KTEPS) 1925.63
# Epoch 00325 | Time(s) 0.0069 | Loss 0.2379 | Accuracy 0.7880 | ETputs(KTEPS) 1926.16
# Epoch 00326 | Time(s) 0.0069 | Loss 0.2568 | Accuracy 0.7880 | ETputs(KTEPS) 1926.03
# Epoch 00327 | Time(s) 0.0069 | Loss 0.2670 | Accuracy 0.7880 | ETputs(KTEPS) 1924.68
# Epoch 00328 | Time(s) 0.0069 | Loss 0.2444 | Accuracy 0.7900 | ETputs(KTEPS) 1924.10
# Epoch 00329 | Time(s) 0.0069 | Loss 0.2360 | Accuracy 0.7880 | ETputs(KTEPS) 1924.85
# Epoch 00330 | Time(s) 0.0069 | Loss 0.2342 | Accuracy 0.7900 | ETputs(KTEPS) 1925.24
# Epoch 00331 | Time(s) 0.0069 | Loss 0.2642 | Accuracy 0.7880 | ETputs(KTEPS) 1925.88
# Epoch 00332 | Time(s) 0.0069 | Loss 0.2521 | Accuracy 0.7860 | ETputs(KTEPS) 1926.64
# Epoch 00333 | Time(s) 0.0069 | Loss 0.2677 | Accuracy 0.7840 | ETputs(KTEPS) 1926.90
# Epoch 00334 | Time(s) 0.0069 | Loss 0.2660 | Accuracy 0.7900 | ETputs(KTEPS) 1927.12
# Epoch 00335 | Time(s) 0.0069 | Loss 0.2486 | Accuracy 0.7900 | ETputs(KTEPS) 1927.97
# Epoch 00336 | Time(s) 0.0069 | Loss 0.2247 | Accuracy 0.7860 | ETputs(KTEPS) 1928.55
# Epoch 00337 | Time(s) 0.0069 | Loss 0.2430 | Accuracy 0.7880 | ETputs(KTEPS) 1929.09
# Epoch 00338 | Time(s) 0.0069 | Loss 0.2353 | Accuracy 0.7920 | ETputs(KTEPS) 1929.26
# Epoch 00339 | Time(s) 0.0069 | Loss 0.2417 | Accuracy 0.7920 | ETputs(KTEPS) 1929.63
# Epoch 00340 | Time(s) 0.0069 | Loss 0.2544 | Accuracy 0.7900 | ETputs(KTEPS) 1930.25
# Epoch 00341 | Time(s) 0.0069 | Loss 0.2324 | Accuracy 0.7940 | ETputs(KTEPS) 1931.07
# Epoch 00342 | Time(s) 0.0069 | Loss 0.2222 | Accuracy 0.7940 | ETputs(KTEPS) 1930.83
# Epoch 00343 | Time(s) 0.0069 | Loss 0.2269 | Accuracy 0.7880 | ETputs(KTEPS) 1931.01
# Epoch 00344 | Time(s) 0.0069 | Loss 0.2773 | Accuracy 0.7920 | ETputs(KTEPS) 1931.36
# Epoch 00345 | Time(s) 0.0069 | Loss 0.2462 | Accuracy 0.7920 | ETputs(KTEPS) 1930.73
# Epoch 00346 | Time(s) 0.0069 | Loss 0.2306 | Accuracy 0.7900 | ETputs(KTEPS) 1930.11
# Epoch 00347 | Time(s) 0.0069 | Loss 0.2462 | Accuracy 0.7900 | ETputs(KTEPS) 1929.33
# Epoch 00348 | Time(s) 0.0069 | Loss 0.2446 | Accuracy 0.7880 | ETputs(KTEPS) 1929.76
# Epoch 00349 | Time(s) 0.0069 | Loss 0.1958 | Accuracy 0.7880 | ETputs(KTEPS) 1930.42
# Epoch 00350 | Time(s) 0.0069 | Loss 0.2681 | Accuracy 0.7880 | ETputs(KTEPS) 1930.94
# Epoch 00351 | Time(s) 0.0069 | Loss 0.2504 | Accuracy 0.7880 | ETputs(KTEPS) 1931.40
# Epoch 00352 | Time(s) 0.0069 | Loss 0.2071 | Accuracy 0.7880 | ETputs(KTEPS) 1931.72
# Epoch 00353 | Time(s) 0.0069 | Loss 0.2123 | Accuracy 0.7880 | ETputs(KTEPS) 1932.35
# Epoch 00354 | Time(s) 0.0069 | Loss 0.2404 | Accuracy 0.7880 | ETputs(KTEPS) 1932.84
# Epoch 00355 | Time(s) 0.0069 | Loss 0.2405 | Accuracy 0.7900 | ETputs(KTEPS) 1933.44
# Epoch 00356 | Time(s) 0.0069 | Loss 0.2523 | Accuracy 0.7900 | ETputs(KTEPS) 1933.53
# Epoch 00357 | Time(s) 0.0069 | Loss 0.1858 | Accuracy 0.7900 | ETputs(KTEPS) 1933.93
# Epoch 00358 | Time(s) 0.0069 | Loss 0.2250 | Accuracy 0.7940 | ETputs(KTEPS) 1934.49
# Epoch 00359 | Time(s) 0.0069 | Loss 0.2670 | Accuracy 0.7900 | ETputs(KTEPS) 1935.23
# Epoch 00360 | Time(s) 0.0069 | Loss 0.2586 | Accuracy 0.7880 | ETputs(KTEPS) 1935.64
# Epoch 00361 | Time(s) 0.0069 | Loss 0.2261 | Accuracy 0.7900 | ETputs(KTEPS) 1935.70
# Epoch 00362 | Time(s) 0.0069 | Loss 0.2658 | Accuracy 0.7880 | ETputs(KTEPS) 1935.96
# Epoch 00363 | Time(s) 0.0069 | Loss 0.2505 | Accuracy 0.7860 | ETputs(KTEPS) 1936.24
# Epoch 00364 | Time(s) 0.0069 | Loss 0.2486 | Accuracy 0.7860 | ETputs(KTEPS) 1935.72
# Epoch 00365 | Time(s) 0.0069 | Loss 0.2428 | Accuracy 0.7880 | ETputs(KTEPS) 1935.04
# Epoch 00366 | Time(s) 0.0069 | Loss 0.2318 | Accuracy 0.7920 | ETputs(KTEPS) 1933.78
# Epoch 00367 | Time(s) 0.0069 | Loss 0.2155 | Accuracy 0.7940 | ETputs(KTEPS) 1933.81
# Epoch 00368 | Time(s) 0.0069 | Loss 0.2424 | Accuracy 0.7940 | ETputs(KTEPS) 1933.93
# Epoch 00369 | Time(s) 0.0069 | Loss 0.2706 | Accuracy 0.7920 | ETputs(KTEPS) 1933.64
# Epoch 00370 | Time(s) 0.0069 | Loss 0.2123 | Accuracy 0.7920 | ETputs(KTEPS) 1933.76
# Epoch 00371 | Time(s) 0.0069 | Loss 0.2204 | Accuracy 0.7900 | ETputs(KTEPS) 1934.06
# Epoch 00372 | Time(s) 0.0069 | Loss 0.2663 | Accuracy 0.7840 | ETputs(KTEPS) 1934.20
# Epoch 00373 | Time(s) 0.0069 | Loss 0.2376 | Accuracy 0.7860 | ETputs(KTEPS) 1934.03
# Epoch 00374 | Time(s) 0.0069 | Loss 0.2329 | Accuracy 0.7880 | ETputs(KTEPS) 1934.24
# Epoch 00375 | Time(s) 0.0069 | Loss 0.2385 | Accuracy 0.7860 | ETputs(KTEPS) 1933.97
# Epoch 00376 | Time(s) 0.0069 | Loss 0.2198 | Accuracy 0.7820 | ETputs(KTEPS) 1933.68
# Epoch 00377 | Time(s) 0.0069 | Loss 0.2450 | Accuracy 0.7820 | ETputs(KTEPS) 1933.85
# Epoch 00378 | Time(s) 0.0069 | Loss 0.2021 | Accuracy 0.7800 | ETputs(KTEPS) 1934.42
# Epoch 00379 | Time(s) 0.0069 | Loss 0.2644 | Accuracy 0.7820 | ETputs(KTEPS) 1934.58
# Epoch 00380 | Time(s) 0.0069 | Loss 0.2099 | Accuracy 0.7840 | ETputs(KTEPS) 1934.95
# Epoch 00381 | Time(s) 0.0069 | Loss 0.2051 | Accuracy 0.7840 | ETputs(KTEPS) 1935.23
# Epoch 00382 | Time(s) 0.0069 | Loss 0.2178 | Accuracy 0.7880 | ETputs(KTEPS) 1935.31
# Epoch 00383 | Time(s) 0.0069 | Loss 0.2033 | Accuracy 0.7880 | ETputs(KTEPS) 1934.88
# Epoch 00384 | Time(s) 0.0069 | Loss 0.1980 | Accuracy 0.7860 | ETputs(KTEPS) 1934.81
# Epoch 00385 | Time(s) 0.0069 | Loss 0.2423 | Accuracy 0.7840 | ETputs(KTEPS) 1934.58
# Epoch 00386 | Time(s) 0.0069 | Loss 0.2461 | Accuracy 0.7840 | ETputs(KTEPS) 1934.83
# Epoch 00387 | Time(s) 0.0069 | Loss 0.2259 | Accuracy 0.7860 | ETputs(KTEPS) 1935.53
# Epoch 00388 | Time(s) 0.0069 | Loss 0.2304 | Accuracy 0.7880 | ETputs(KTEPS) 1936.15
# Epoch 00389 | Time(s) 0.0068 | Loss 0.2265 | Accuracy 0.7840 | ETputs(KTEPS) 1936.72
# Epoch 00390 | Time(s) 0.0068 | Loss 0.2274 | Accuracy 0.7860 | ETputs(KTEPS) 1937.29
# Epoch 00391 | Time(s) 0.0068 | Loss 0.2643 | Accuracy 0.7800 | ETputs(KTEPS) 1937.55
# Epoch 00392 | Time(s) 0.0068 | Loss 0.2256 | Accuracy 0.7820 | ETputs(KTEPS) 1938.05
# Epoch 00393 | Time(s) 0.0068 | Loss 0.2210 | Accuracy 0.7860 | ETputs(KTEPS) 1938.14
# Epoch 00394 | Time(s) 0.0068 | Loss 0.2375 | Accuracy 0.7860 | ETputs(KTEPS) 1938.41
# Epoch 00395 | Time(s) 0.0068 | Loss 0.2360 | Accuracy 0.7880 | ETputs(KTEPS) 1938.90
# Epoch 00396 | Time(s) 0.0068 | Loss 0.2309 | Accuracy 0.7840 | ETputs(KTEPS) 1939.33
# Epoch 00397 | Time(s) 0.0068 | Loss 0.2271 | Accuracy 0.7860 | ETputs(KTEPS) 1939.78
# Epoch 00398 | Time(s) 0.0068 | Loss 0.2356 | Accuracy 0.7900 | ETputs(KTEPS) 1939.95
# Epoch 00399 | Time(s) 0.0068 | Loss 0.2492 | Accuracy 0.7900 | ETputs(KTEPS) 1940.53
# Epoch 00400 | Time(s) 0.0068 | Loss 0.2302 | Accuracy 0.7880 | ETputs(KTEPS) 1940.74
# Epoch 00401 | Time(s) 0.0068 | Loss 0.1853 | Accuracy 0.7900 | ETputs(KTEPS) 1940.48
# Epoch 00402 | Time(s) 0.0068 | Loss 0.2097 | Accuracy 0.7920 | ETputs(KTEPS) 1940.26
# Epoch 00403 | Time(s) 0.0068 | Loss 0.2097 | Accuracy 0.7900 | ETputs(KTEPS) 1939.21
# Epoch 00404 | Time(s) 0.0068 | Loss 0.2207 | Accuracy 0.7900 | ETputs(KTEPS) 1939.31
# Epoch 00405 | Time(s) 0.0068 | Loss 0.2184 | Accuracy 0.7880 | ETputs(KTEPS) 1939.78
# Epoch 00406 | Time(s) 0.0068 | Loss 0.2317 | Accuracy 0.7880 | ETputs(KTEPS) 1940.20
# Epoch 00407 | Time(s) 0.0068 | Loss 0.2014 | Accuracy 0.7900 | ETputs(KTEPS) 1940.00
# Epoch 00408 | Time(s) 0.0068 | Loss 0.2331 | Accuracy 0.7880 | ETputs(KTEPS) 1939.91
# Epoch 00409 | Time(s) 0.0068 | Loss 0.2051 | Accuracy 0.7860 | ETputs(KTEPS) 1939.54
# Epoch 00410 | Time(s) 0.0068 | Loss 0.2247 | Accuracy 0.7860 | ETputs(KTEPS) 1939.47
# Epoch 00411 | Time(s) 0.0068 | Loss 0.2258 | Accuracy 0.7900 | ETputs(KTEPS) 1939.41
# Epoch 00412 | Time(s) 0.0068 | Loss 0.2302 | Accuracy 0.7880 | ETputs(KTEPS) 1939.16
# Epoch 00413 | Time(s) 0.0068 | Loss 0.2291 | Accuracy 0.7880 | ETputs(KTEPS) 1939.03
# Epoch 00414 | Time(s) 0.0068 | Loss 0.2317 | Accuracy 0.7900 | ETputs(KTEPS) 1939.12
# Epoch 00415 | Time(s) 0.0068 | Loss 0.2123 | Accuracy 0.7940 | ETputs(KTEPS) 1938.82
# Epoch 00416 | Time(s) 0.0068 | Loss 0.2194 | Accuracy 0.7960 | ETputs(KTEPS) 1938.52
# Epoch 00417 | Time(s) 0.0068 | Loss 0.2025 | Accuracy 0.7940 | ETputs(KTEPS) 1938.41
# Epoch 00418 | Time(s) 0.0068 | Loss 0.2128 | Accuracy 0.7920 | ETputs(KTEPS) 1937.99
# Epoch 00419 | Time(s) 0.0068 | Loss 0.2077 | Accuracy 0.7880 | ETputs(KTEPS) 1937.54
# Epoch 00420 | Time(s) 0.0068 | Loss 0.2325 | Accuracy 0.7840 | ETputs(KTEPS) 1936.87
# Epoch 00421 | Time(s) 0.0069 | Loss 0.2068 | Accuracy 0.7860 | ETputs(KTEPS) 1936.20
# Epoch 00422 | Time(s) 0.0068 | Loss 0.1995 | Accuracy 0.7920 | ETputs(KTEPS) 1936.36
# Epoch 00423 | Time(s) 0.0068 | Loss 0.2038 | Accuracy 0.7880 | ETputs(KTEPS) 1936.39
# Epoch 00424 | Time(s) 0.0069 | Loss 0.2285 | Accuracy 0.7860 | ETputs(KTEPS) 1936.27
# Epoch 00425 | Time(s) 0.0068 | Loss 0.2200 | Accuracy 0.7860 | ETputs(KTEPS) 1936.40
# Epoch 00426 | Time(s) 0.0068 | Loss 0.1997 | Accuracy 0.7880 | ETputs(KTEPS) 1936.44
# Epoch 00427 | Time(s) 0.0069 | Loss 0.2223 | Accuracy 0.7900 | ETputs(KTEPS) 1936.27
# Epoch 00428 | Time(s) 0.0069 | Loss 0.2113 | Accuracy 0.7900 | ETputs(KTEPS) 1936.31
# Epoch 00429 | Time(s) 0.0069 | Loss 0.2198 | Accuracy 0.7960 | ETputs(KTEPS) 1936.06
# Epoch 00430 | Time(s) 0.0069 | Loss 0.2255 | Accuracy 0.7920 | ETputs(KTEPS) 1935.83
# Epoch 00431 | Time(s) 0.0069 | Loss 0.2234 | Accuracy 0.7920 | ETputs(KTEPS) 1935.84
# Epoch 00432 | Time(s) 0.0069 | Loss 0.1978 | Accuracy 0.7920 | ETputs(KTEPS) 1936.01
# Epoch 00433 | Time(s) 0.0069 | Loss 0.2150 | Accuracy 0.7840 | ETputs(KTEPS) 1936.15
# Epoch 00434 | Time(s) 0.0069 | Loss 0.2190 | Accuracy 0.7840 | ETputs(KTEPS) 1935.66
# Epoch 00435 | Time(s) 0.0069 | Loss 0.2129 | Accuracy 0.7820 | ETputs(KTEPS) 1935.58
# Epoch 00436 | Time(s) 0.0069 | Loss 0.1859 | Accuracy 0.7860 | ETputs(KTEPS) 1935.12
# Epoch 00437 | Time(s) 0.0069 | Loss 0.2289 | Accuracy 0.7820 | ETputs(KTEPS) 1934.60
# Epoch 00438 | Time(s) 0.0069 | Loss 0.2282 | Accuracy 0.7820 | ETputs(KTEPS) 1933.87
# Epoch 00439 | Time(s) 0.0069 | Loss 0.2048 | Accuracy 0.7880 | ETputs(KTEPS) 1933.98
# Epoch 00440 | Time(s) 0.0069 | Loss 0.2692 | Accuracy 0.7900 | ETputs(KTEPS) 1934.06
# Epoch 00441 | Time(s) 0.0069 | Loss 0.2541 | Accuracy 0.7940 | ETputs(KTEPS) 1934.12
# Epoch 00442 | Time(s) 0.0069 | Loss 0.2298 | Accuracy 0.7940 | ETputs(KTEPS) 1934.08
# Epoch 00443 | Time(s) 0.0069 | Loss 0.2171 | Accuracy 0.7960 | ETputs(KTEPS) 1934.06
# Epoch 00444 | Time(s) 0.0069 | Loss 0.2309 | Accuracy 0.7880 | ETputs(KTEPS) 1934.18
# Epoch 00445 | Time(s) 0.0069 | Loss 0.2029 | Accuracy 0.7880 | ETputs(KTEPS) 1934.13
# Epoch 00446 | Time(s) 0.0069 | Loss 0.2215 | Accuracy 0.7880 | ETputs(KTEPS) 1934.27
# Epoch 00447 | Time(s) 0.0069 | Loss 0.2176 | Accuracy 0.7840 | ETputs(KTEPS) 1934.13
# Epoch 00448 | Time(s) 0.0069 | Loss 0.2142 | Accuracy 0.7840 | ETputs(KTEPS) 1933.93
# Epoch 00449 | Time(s) 0.0069 | Loss 0.1981 | Accuracy 0.7820 | ETputs(KTEPS) 1933.98
# Epoch 00450 | Time(s) 0.0069 | Loss 0.2082 | Accuracy 0.7860 | ETputs(KTEPS) 1934.14
# Epoch 00451 | Time(s) 0.0069 | Loss 0.1974 | Accuracy 0.7880 | ETputs(KTEPS) 1933.64
# Epoch 00452 | Time(s) 0.0069 | Loss 0.1901 | Accuracy 0.7900 | ETputs(KTEPS) 1933.46
# Epoch 00453 | Time(s) 0.0069 | Loss 0.2513 | Accuracy 0.7920 | ETputs(KTEPS) 1932.86
# Epoch 00454 | Time(s) 0.0069 | Loss 0.1817 | Accuracy 0.7960 | ETputs(KTEPS) 1932.33
# Epoch 00455 | Time(s) 0.0069 | Loss 0.2223 | Accuracy 0.7980 | ETputs(KTEPS) 1931.57
# Epoch 00456 | Time(s) 0.0069 | Loss 0.1973 | Accuracy 0.7960 | ETputs(KTEPS) 1931.41
# Epoch 00457 | Time(s) 0.0069 | Loss 0.2285 | Accuracy 0.7960 | ETputs(KTEPS) 1931.62
# Epoch 00458 | Time(s) 0.0069 | Loss 0.2303 | Accuracy 0.7900 | ETputs(KTEPS) 1931.50
# Epoch 00459 | Time(s) 0.0069 | Loss 0.2092 | Accuracy 0.7840 | ETputs(KTEPS) 1931.26
# Epoch 00460 | Time(s) 0.0069 | Loss 0.1885 | Accuracy 0.7840 | ETputs(KTEPS) 1931.03
# Epoch 00461 | Time(s) 0.0069 | Loss 0.2166 | Accuracy 0.7820 | ETputs(KTEPS) 1931.11
# Epoch 00462 | Time(s) 0.0069 | Loss 0.2202 | Accuracy 0.7840 | ETputs(KTEPS) 1931.19
# Epoch 00463 | Time(s) 0.0069 | Loss 0.1938 | Accuracy 0.7860 | ETputs(KTEPS) 1931.19
# Epoch 00464 | Time(s) 0.0069 | Loss 0.2035 | Accuracy 0.7920 | ETputs(KTEPS) 1930.78
# Epoch 00465 | Time(s) 0.0069 | Loss 0.2389 | Accuracy 0.7960 | ETputs(KTEPS) 1930.83
# Epoch 00466 | Time(s) 0.0069 | Loss 0.1971 | Accuracy 0.7960 | ETputs(KTEPS) 1930.86
# Epoch 00467 | Time(s) 0.0069 | Loss 0.2361 | Accuracy 0.7980 | ETputs(KTEPS) 1931.08
# Epoch 00468 | Time(s) 0.0069 | Loss 0.2367 | Accuracy 0.7980 | ETputs(KTEPS) 1931.01
# Epoch 00469 | Time(s) 0.0069 | Loss 0.2597 | Accuracy 0.7940 | ETputs(KTEPS) 1930.91
# Epoch 00470 | Time(s) 0.0069 | Loss 0.2017 | Accuracy 0.7880 | ETputs(KTEPS) 1930.26
# Epoch 00471 | Time(s) 0.0069 | Loss 0.1973 | Accuracy 0.7820 | ETputs(KTEPS) 1929.62
# Epoch 00472 | Time(s) 0.0069 | Loss 0.2217 | Accuracy 0.7780 | ETputs(KTEPS) 1929.07
# Epoch 00473 | Time(s) 0.0069 | Loss 0.1929 | Accuracy 0.7800 | ETputs(KTEPS) 1928.78
# Epoch 00474 | Time(s) 0.0069 | Loss 0.2386 | Accuracy 0.7840 | ETputs(KTEPS) 1928.75
# Epoch 00475 | Time(s) 0.0069 | Loss 0.2181 | Accuracy 0.7920 | ETputs(KTEPS) 1928.84
# Epoch 00476 | Time(s) 0.0069 | Loss 0.2348 | Accuracy 0.7940 | ETputs(KTEPS) 1928.66
# Epoch 00477 | Time(s) 0.0069 | Loss 0.2322 | Accuracy 0.7940 | ETputs(KTEPS) 1928.53
# Epoch 00478 | Time(s) 0.0069 | Loss 0.2158 | Accuracy 0.7980 | ETputs(KTEPS) 1928.53
# Epoch 00479 | Time(s) 0.0069 | Loss 0.2059 | Accuracy 0.7960 | ETputs(KTEPS) 1928.56
# Epoch 00480 | Time(s) 0.0069 | Loss 0.2309 | Accuracy 0.7940 | ETputs(KTEPS) 1928.39
# Epoch 00481 | Time(s) 0.0069 | Loss 0.1969 | Accuracy 0.7880 | ETputs(KTEPS) 1928.36
# Epoch 00482 | Time(s) 0.0069 | Loss 0.1805 | Accuracy 0.7860 | ETputs(KTEPS) 1928.52
# Epoch 00483 | Time(s) 0.0069 | Loss 0.1871 | Accuracy 0.7820 | ETputs(KTEPS) 1928.35
# Epoch 00484 | Time(s) 0.0069 | Loss 0.2153 | Accuracy 0.7840 | ETputs(KTEPS) 1928.22
# Epoch 00485 | Time(s) 0.0069 | Loss 0.1990 | Accuracy 0.7820 | ETputs(KTEPS) 1927.81
# Epoch 00486 | Time(s) 0.0069 | Loss 0.2133 | Accuracy 0.7920 | ETputs(KTEPS) 1927.92
# Epoch 00487 | Time(s) 0.0069 | Loss 0.1951 | Accuracy 0.7880 | ETputs(KTEPS) 1927.79
# Epoch 00488 | Time(s) 0.0069 | Loss 0.1966 | Accuracy 0.7880 | ETputs(KTEPS) 1927.33
# Epoch 00489 | Time(s) 0.0069 | Loss 0.1976 | Accuracy 0.7860 | ETputs(KTEPS) 1927.30
# Epoch 00490 | Time(s) 0.0069 | Loss 0.1858 | Accuracy 0.7940 | ETputs(KTEPS) 1927.18
# Epoch 00491 | Time(s) 0.0069 | Loss 0.1947 | Accuracy 0.7940 | ETputs(KTEPS) 1927.46
# Epoch 00492 | Time(s) 0.0069 | Loss 0.1930 | Accuracy 0.7940 | ETputs(KTEPS) 1928.00
# Epoch 00493 | Time(s) 0.0069 | Loss 0.1833 | Accuracy 0.7940 | ETputs(KTEPS) 1928.17
# Epoch 00494 | Time(s) 0.0069 | Loss 0.2263 | Accuracy 0.7980 | ETputs(KTEPS) 1928.63
# Epoch 00495 | Time(s) 0.0069 | Loss 0.2077 | Accuracy 0.7920 | ETputs(KTEPS) 1929.18
# Epoch 00496 | Time(s) 0.0069 | Loss 0.1828 | Accuracy 0.7860 | ETputs(KTEPS) 1929.60
# Epoch 00497 | Time(s) 0.0069 | Loss 0.2016 | Accuracy 0.7820 | ETputs(KTEPS) 1929.90
# Epoch 00498 | Time(s) 0.0069 | Loss 0.2105 | Accuracy 0.7820 | ETputs(KTEPS) 1930.21
# Epoch 00499 | Time(s) 0.0069 | Loss 0.2128 | Accuracy 0.7880 | ETputs(KTEPS) 1930.26
# Epoch 00500 | Time(s) 0.0069 | Loss 0.2140 | Accuracy 0.7920 | ETputs(KTEPS) 1930.66
# Epoch 00501 | Time(s) 0.0069 | Loss 0.1942 | Accuracy 0.7940 | ETputs(KTEPS) 1931.14
# Epoch 00502 | Time(s) 0.0069 | Loss 0.2220 | Accuracy 0.7960 | ETputs(KTEPS) 1931.27
# Epoch 00503 | Time(s) 0.0069 | Loss 0.2137 | Accuracy 0.7960 | ETputs(KTEPS) 1931.10
# Epoch 00504 | Time(s) 0.0069 | Loss 0.2199 | Accuracy 0.7960 | ETputs(KTEPS) 1931.35
# Epoch 00505 | Time(s) 0.0069 | Loss 0.1902 | Accuracy 0.7860 | ETputs(KTEPS) 1931.46
# Epoch 00506 | Time(s) 0.0069 | Loss 0.2076 | Accuracy 0.7880 | ETputs(KTEPS) 1931.29
# Epoch 00507 | Time(s) 0.0069 | Loss 0.2263 | Accuracy 0.7900 | ETputs(KTEPS) 1931.27
# Epoch 00508 | Time(s) 0.0069 | Loss 0.2260 | Accuracy 0.7920 | ETputs(KTEPS) 1930.32
# Epoch 00509 | Time(s) 0.0069 | Loss 0.2090 | Accuracy 0.7860 | ETputs(KTEPS) 1930.11
# Epoch 00510 | Time(s) 0.0069 | Loss 0.2006 | Accuracy 0.7860 | ETputs(KTEPS) 1930.36
# Epoch 00511 | Time(s) 0.0069 | Loss 0.2204 | Accuracy 0.7840 | ETputs(KTEPS) 1930.70
# Epoch 00512 | Time(s) 0.0069 | Loss 0.1789 | Accuracy 0.7800 | ETputs(KTEPS) 1930.85
# Epoch 00513 | Time(s) 0.0069 | Loss 0.1964 | Accuracy 0.7780 | ETputs(KTEPS) 1931.30
# Epoch 00514 | Time(s) 0.0069 | Loss 0.2114 | Accuracy 0.7800 | ETputs(KTEPS) 1931.90
# Epoch 00515 | Time(s) 0.0069 | Loss 0.1863 | Accuracy 0.7780 | ETputs(KTEPS) 1932.20
# Epoch 00516 | Time(s) 0.0069 | Loss 0.2288 | Accuracy 0.7780 | ETputs(KTEPS) 1932.70
# Epoch 00517 | Time(s) 0.0069 | Loss 0.2352 | Accuracy 0.7820 | ETputs(KTEPS) 1932.21
# Epoch 00518 | Time(s) 0.0069 | Loss 0.1834 | Accuracy 0.7840 | ETputs(KTEPS) 1932.40
# Epoch 00519 | Time(s) 0.0069 | Loss 0.2217 | Accuracy 0.7840 | ETputs(KTEPS) 1932.81
# Epoch 00520 | Time(s) 0.0069 | Loss 0.2136 | Accuracy 0.7840 | ETputs(KTEPS) 1933.10
# Epoch 00521 | Time(s) 0.0069 | Loss 0.2071 | Accuracy 0.7780 | ETputs(KTEPS) 1933.46
# Epoch 00522 | Time(s) 0.0069 | Loss 0.2352 | Accuracy 0.7820 | ETputs(KTEPS) 1933.71
# Epoch 00523 | Time(s) 0.0069 | Loss 0.2063 | Accuracy 0.7860 | ETputs(KTEPS) 1933.81
# Epoch 00524 | Time(s) 0.0069 | Loss 0.2463 | Accuracy 0.7860 | ETputs(KTEPS) 1933.96
# Epoch 00525 | Time(s) 0.0069 | Loss 0.1876 | Accuracy 0.7880 | ETputs(KTEPS) 1933.95
# Epoch 00526 | Time(s) 0.0069 | Loss 0.2078 | Accuracy 0.7880 | ETputs(KTEPS) 1933.77
# Epoch 00527 | Time(s) 0.0069 | Loss 0.2008 | Accuracy 0.7900 | ETputs(KTEPS) 1932.72
# Epoch 00528 | Time(s) 0.0069 | Loss 0.2101 | Accuracy 0.7860 | ETputs(KTEPS) 1932.99
# Epoch 00529 | Time(s) 0.0069 | Loss 0.1798 | Accuracy 0.7840 | ETputs(KTEPS) 1932.68
# Epoch 00530 | Time(s) 0.0069 | Loss 0.2292 | Accuracy 0.7840 | ETputs(KTEPS) 1932.57
# Epoch 00531 | Time(s) 0.0069 | Loss 0.2014 | Accuracy 0.7860 | ETputs(KTEPS) 1932.54
# Epoch 00532 | Time(s) 0.0069 | Loss 0.2059 | Accuracy 0.7880 | ETputs(KTEPS) 1932.72
# Epoch 00533 | Time(s) 0.0069 | Loss 0.1607 | Accuracy 0.7940 | ETputs(KTEPS) 1932.51
# Epoch 00534 | Time(s) 0.0069 | Loss 0.2183 | Accuracy 0.7940 | ETputs(KTEPS) 1932.37
# Epoch 00535 | Time(s) 0.0069 | Loss 0.2094 | Accuracy 0.7940 | ETputs(KTEPS) 1932.15
# Epoch 00536 | Time(s) 0.0069 | Loss 0.1602 | Accuracy 0.7940 | ETputs(KTEPS) 1932.48
# Epoch 00537 | Time(s) 0.0069 | Loss 0.1892 | Accuracy 0.7920 | ETputs(KTEPS) 1932.62
# Epoch 00538 | Time(s) 0.0069 | Loss 0.2078 | Accuracy 0.7920 | ETputs(KTEPS) 1933.06
# Epoch 00539 | Time(s) 0.0069 | Loss 0.2027 | Accuracy 0.7900 | ETputs(KTEPS) 1933.09
# Epoch 00540 | Time(s) 0.0069 | Loss 0.2199 | Accuracy 0.7860 | ETputs(KTEPS) 1933.41
# Epoch 00541 | Time(s) 0.0069 | Loss 0.2228 | Accuracy 0.7840 | ETputs(KTEPS) 1933.58
# Epoch 00542 | Time(s) 0.0069 | Loss 0.1977 | Accuracy 0.7820 | ETputs(KTEPS) 1933.18
# Epoch 00543 | Time(s) 0.0069 | Loss 0.1674 | Accuracy 0.7840 | ETputs(KTEPS) 1932.57
# Epoch 00544 | Time(s) 0.0069 | Loss 0.2243 | Accuracy 0.7880 | ETputs(KTEPS) 1932.35
# Epoch 00545 | Time(s) 0.0069 | Loss 0.1944 | Accuracy 0.7900 | ETputs(KTEPS) 1932.74
# Epoch 00546 | Time(s) 0.0069 | Loss 0.2159 | Accuracy 0.7900 | ETputs(KTEPS) 1932.95
# Epoch 00547 | Time(s) 0.0069 | Loss 0.1942 | Accuracy 0.7940 | ETputs(KTEPS) 1933.22
# Epoch 00548 | Time(s) 0.0069 | Loss 0.1867 | Accuracy 0.7940 | ETputs(KTEPS) 1933.66
# Epoch 00549 | Time(s) 0.0069 | Loss 0.2147 | Accuracy 0.7940 | ETputs(KTEPS) 1933.98
# Epoch 00550 | Time(s) 0.0069 | Loss 0.2114 | Accuracy 0.7920 | ETputs(KTEPS) 1934.32
# Epoch 00551 | Time(s) 0.0069 | Loss 0.1790 | Accuracy 0.7900 | ETputs(KTEPS) 1934.71
# Epoch 00552 | Time(s) 0.0069 | Loss 0.1895 | Accuracy 0.7860 | ETputs(KTEPS) 1935.07
# Epoch 00553 | Time(s) 0.0069 | Loss 0.2302 | Accuracy 0.7880 | ETputs(KTEPS) 1935.25
# Epoch 00554 | Time(s) 0.0069 | Loss 0.2212 | Accuracy 0.7920 | ETputs(KTEPS) 1935.41
# Epoch 00555 | Time(s) 0.0069 | Loss 0.1698 | Accuracy 0.7940 | ETputs(KTEPS) 1935.59
# Epoch 00556 | Time(s) 0.0069 | Loss 0.2051 | Accuracy 0.7940 | ETputs(KTEPS) 1935.99
# ...
# Epoch 00813 | Time(s) 0.0068 | Loss 0.1878 | Accuracy 0.7880 | ETputs(KTEPS) 1946.02
# Epoch 00814 | Time(s) 0.0068 | Loss 0.2252 | Accuracy 0.7880 | ETputs(KTEPS) 1945.90
# Epoch 00815 | Time(s) 0.0068 | Loss 0.2096 | Accuracy 0.7880 | ETputs(KTEPS) 1945.35
# Epoch 00816 | Time(s) 0.0068 | Loss 0.1929 | Accuracy 0.7880 | ETputs(KTEPS) 1944.76
# Epoch 00817 | Time(s) 0.0068 | Loss 0.1881 | Accuracy 0.7860 | ETputs(KTEPS) 1944.72
# Epoch 00818 | Time(s) 0.0068 | Loss 0.1551 | Accuracy 0.7860 | ETputs(KTEPS) 1944.68
# Epoch 00819 | Time(s) 0.0068 | Loss 0.1758 | Accuracy 0.7880 | ETputs(KTEPS) 1944.55
# Epoch 00820 | Time(s) 0.0068 | Loss 0.1964 | Accuracy 0.7900 | ETputs(KTEPS) 1944.56
# Epoch 00821 | Time(s) 0.0068 | Loss 0.1749 | Accuracy 0.7960 | ETputs(KTEPS) 1944.62
# Epoch 00822 | Time(s) 0.0068 | Loss 0.1837 | Accuracy 0.7980 | ETputs(KTEPS) 1944.60
# Epoch 00823 | Time(s) 0.0068 | Loss 0.1656 | Accuracy 0.7960 | ETputs(KTEPS) 1944.37
# Epoch 00824 | Time(s) 0.0068 | Loss 0.2000 | Accuracy 0.7940 | ETputs(KTEPS) 1944.27
# Epoch 00825 | Time(s) 0.0068 | Loss 0.1909 | Accuracy 0.7960 | ETputs(KTEPS) 1943.91
# Epoch 00826 | Time(s) 0.0068 | Loss 0.1801 | Accuracy 0.7940 | ETputs(KTEPS) 1943.68
# Epoch 00827 | Time(s) 0.0068 | Loss 0.1789 | Accuracy 0.7860 | ETputs(KTEPS) 1943.64
# Epoch 00828 | Time(s) 0.0068 | Loss 0.2242 | Accuracy 0.7840 | ETputs(KTEPS) 1943.72
# Epoch 00829 | Time(s) 0.0068 | Loss 0.2057 | Accuracy 0.7800 | ETputs(KTEPS) 1943.58
# Epoch 00830 | Time(s) 0.0068 | Loss 0.1775 | Accuracy 0.7800 | ETputs(KTEPS) 1943.50
# Epoch 00831 | Time(s) 0.0068 | Loss 0.1746 | Accuracy 0.7860 | ETputs(KTEPS) 1943.10
# Epoch 00832 | Time(s) 0.0068 | Loss 0.1835 | Accuracy 0.7860 | ETputs(KTEPS) 1942.62
# Epoch 00833 | Time(s) 0.0068 | Loss 0.1580 | Accuracy 0.7900 | ETputs(KTEPS) 1942.44
# Epoch 00834 | Time(s) 0.0068 | Loss 0.1795 | Accuracy 0.7980 | ETputs(KTEPS) 1942.21
# Epoch 00835 | Time(s) 0.0068 | Loss 0.1895 | Accuracy 0.7960 | ETputs(KTEPS) 1942.07
# Epoch 00836 | Time(s) 0.0068 | Loss 0.1907 | Accuracy 0.7960 | ETputs(KTEPS) 1942.18
# Epoch 00837 | Time(s) 0.0068 | Loss 0.1885 | Accuracy 0.7960 | ETputs(KTEPS) 1942.25
# Epoch 00838 | Time(s) 0.0068 | Loss 0.2072 | Accuracy 0.7920 | ETputs(KTEPS) 1942.09
# Epoch 00839 | Time(s) 0.0068 | Loss 0.1766 | Accuracy 0.7840 | ETputs(KTEPS) 1942.10
# Epoch 00840 | Time(s) 0.0068 | Loss 0.1807 | Accuracy 0.7820 | ETputs(KTEPS) 1942.36
# Epoch 00841 | Time(s) 0.0068 | Loss 0.1544 | Accuracy 0.7860 | ETputs(KTEPS) 1942.34
# Epoch 00842 | Time(s) 0.0068 | Loss 0.2150 | Accuracy 0.7880 | ETputs(KTEPS) 1942.23
# Epoch 00843 | Time(s) 0.0068 | Loss 0.1794 | Accuracy 0.7900 | ETputs(KTEPS) 1942.52
# Epoch 00844 | Time(s) 0.0068 | Loss 0.2078 | Accuracy 0.7900 | ETputs(KTEPS) 1942.72
# Epoch 00845 | Time(s) 0.0068 | Loss 0.2272 | Accuracy 0.7900 | ETputs(KTEPS) 1942.91
# Epoch 00846 | Time(s) 0.0068 | Loss 0.2033 | Accuracy 0.7920 | ETputs(KTEPS) 1943.07
# Epoch 00847 | Time(s) 0.0068 | Loss 0.1741 | Accuracy 0.7900 | ETputs(KTEPS) 1942.98
# Epoch 00848 | Time(s) 0.0068 | Loss 0.1900 | Accuracy 0.7940 | ETputs(KTEPS) 1943.10
# Epoch 00849 | Time(s) 0.0068 | Loss 0.2124 | Accuracy 0.7900 | ETputs(KTEPS) 1943.05
# Epoch 00850 | Time(s) 0.0068 | Loss 0.1912 | Accuracy 0.7920 | ETputs(KTEPS) 1942.86
# Epoch 00851 | Time(s) 0.0068 | Loss 0.2087 | Accuracy 0.7920 | ETputs(KTEPS) 1942.36
# Epoch 00852 | Time(s) 0.0068 | Loss 0.1429 | Accuracy 0.7920 | ETputs(KTEPS) 1941.93
# Epoch 00853 | Time(s) 0.0068 | Loss 0.1845 | Accuracy 0.7900 | ETputs(KTEPS) 1941.70
# Epoch 00854 | Time(s) 0.0068 | Loss 0.2073 | Accuracy 0.7880 | ETputs(KTEPS) 1941.44
# Epoch 00855 | Time(s) 0.0068 | Loss 0.1964 | Accuracy 0.7840 | ETputs(KTEPS) 1941.56
# Epoch 00856 | Time(s) 0.0068 | Loss 0.1598 | Accuracy 0.7840 | ETputs(KTEPS) 1941.82
# Epoch 00857 | Time(s) 0.0068 | Loss 0.1888 | Accuracy 0.7840 | ETputs(KTEPS) 1942.06
# Epoch 00858 | Time(s) 0.0068 | Loss 0.1920 | Accuracy 0.7840 | ETputs(KTEPS) 1942.33
# Epoch 00859 | Time(s) 0.0068 | Loss 0.1797 | Accuracy 0.7860 | ETputs(KTEPS) 1942.43
# Epoch 00860 | Time(s) 0.0068 | Loss 0.2069 | Accuracy 0.7820 | ETputs(KTEPS) 1942.47
# Epoch 00861 | Time(s) 0.0068 | Loss 0.1918 | Accuracy 0.7840 | ETputs(KTEPS) 1942.65
# Epoch 00862 | Time(s) 0.0068 | Loss 0.2087 | Accuracy 0.7900 | ETputs(KTEPS) 1942.90
# Epoch 00863 | Time(s) 0.0068 | Loss 0.1761 | Accuracy 0.7940 | ETputs(KTEPS) 1943.16
# Epoch 00864 | Time(s) 0.0068 | Loss 0.1806 | Accuracy 0.7940 | ETputs(KTEPS) 1943.09
# Epoch 00865 | Time(s) 0.0068 | Loss 0.1984 | Accuracy 0.7920 | ETputs(KTEPS) 1943.29
# Epoch 00866 | Time(s) 0.0068 | Loss 0.1899 | Accuracy 0.7920 | ETputs(KTEPS) 1943.43
# Epoch 00867 | Time(s) 0.0068 | Loss 0.1942 | Accuracy 0.7880 | ETputs(KTEPS) 1943.31
# Epoch 00868 | Time(s) 0.0068 | Loss 0.1950 | Accuracy 0.7840 | ETputs(KTEPS) 1943.27
# Epoch 00869 | Time(s) 0.0068 | Loss 0.1898 | Accuracy 0.7860 | ETputs(KTEPS) 1942.89
# Epoch 00870 | Time(s) 0.0068 | Loss 0.2085 | Accuracy 0.7860 | ETputs(KTEPS) 1943.05
# Epoch 00871 | Time(s) 0.0068 | Loss 0.1949 | Accuracy 0.7880 | ETputs(KTEPS) 1943.32
# Epoch 00872 | Time(s) 0.0068 | Loss 0.1963 | Accuracy 0.7880 | ETputs(KTEPS) 1943.61
# Epoch 00873 | Time(s) 0.0068 | Loss 0.2135 | Accuracy 0.7900 | ETputs(KTEPS) 1943.83
# Epoch 00874 | Time(s) 0.0068 | Loss 0.1822 | Accuracy 0.7900 | ETputs(KTEPS) 1944.06
# Epoch 00875 | Time(s) 0.0068 | Loss 0.1891 | Accuracy 0.7920 | ETputs(KTEPS) 1944.30
# Epoch 00876 | Time(s) 0.0068 | Loss 0.2046 | Accuracy 0.7920 | ETputs(KTEPS) 1944.60
# Epoch 00877 | Time(s) 0.0068 | Loss 0.1892 | Accuracy 0.7920 | ETputs(KTEPS) 1944.79
# Epoch 00878 | Time(s) 0.0068 | Loss 0.1722 | Accuracy 0.7920 | ETputs(KTEPS) 1944.88
# Epoch 00879 | Time(s) 0.0068 | Loss 0.1812 | Accuracy 0.7900 | ETputs(KTEPS) 1944.88
# Epoch 00880 | Time(s) 0.0068 | Loss 0.2013 | Accuracy 0.7900 | ETputs(KTEPS) 1945.14
# Epoch 00881 | Time(s) 0.0068 | Loss 0.1870 | Accuracy 0.7840 | ETputs(KTEPS) 1945.41
# Epoch 00882 | Time(s) 0.0068 | Loss 0.1925 | Accuracy 0.7840 | ETputs(KTEPS) 1945.76
# Epoch 00883 | Time(s) 0.0068 | Loss 0.1843 | Accuracy 0.7840 | ETputs(KTEPS) 1945.56
# Epoch 00884 | Time(s) 0.0068 | Loss 0.1795 | Accuracy 0.7820 | ETputs(KTEPS) 1945.79
# Epoch 00885 | Time(s) 0.0068 | Loss 0.1900 | Accuracy 0.7820 | ETputs(KTEPS) 1945.86
# Epoch 00886 | Time(s) 0.0068 | Loss 0.1850 | Accuracy 0.7840 | ETputs(KTEPS) 1945.79
# Epoch 00887 | Time(s) 0.0068 | Loss 0.2062 | Accuracy 0.7860 | ETputs(KTEPS) 1945.48
# Epoch 00888 | Time(s) 0.0068 | Loss 0.2085 | Accuracy 0.7840 | ETputs(KTEPS) 1945.39
# Epoch 00889 | Time(s) 0.0068 | Loss 0.1612 | Accuracy 0.7860 | ETputs(KTEPS) 1945.61
# Epoch 00890 | Time(s) 0.0068 | Loss 0.1935 | Accuracy 0.7900 | ETputs(KTEPS) 1945.87
# Epoch 00891 | Time(s) 0.0068 | Loss 0.1867 | Accuracy 0.7920 | ETputs(KTEPS) 1946.08
# Epoch 00892 | Time(s) 0.0068 | Loss 0.1993 | Accuracy 0.7940 | ETputs(KTEPS) 1946.34
# Epoch 00893 | Time(s) 0.0068 | Loss 0.2226 | Accuracy 0.7920 | ETputs(KTEPS) 1946.52
# Epoch 00894 | Time(s) 0.0068 | Loss 0.1691 | Accuracy 0.7880 | ETputs(KTEPS) 1946.83
# Epoch 00895 | Time(s) 0.0068 | Loss 0.1882 | Accuracy 0.7860 | ETputs(KTEPS) 1947.06
# Epoch 00896 | Time(s) 0.0068 | Loss 0.2069 | Accuracy 0.7860 | ETputs(KTEPS) 1947.22
# Epoch 00897 | Time(s) 0.0068 | Loss 0.1754 | Accuracy 0.7840 | ETputs(KTEPS) 1947.38
# Epoch 00898 | Time(s) 0.0068 | Loss 0.1881 | Accuracy 0.7840 | ETputs(KTEPS) 1947.42
# Epoch 00899 | Time(s) 0.0068 | Loss 0.1961 | Accuracy 0.7840 | ETputs(KTEPS) 1947.45
# Epoch 00900 | Time(s) 0.0068 | Loss 0.1944 | Accuracy 0.7860 | ETputs(KTEPS) 1947.70
# Epoch 00901 | Time(s) 0.0068 | Loss 0.2132 | Accuracy 0.7860 | ETputs(KTEPS) 1947.84
# Epoch 00902 | Time(s) 0.0068 | Loss 0.1774 | Accuracy 0.7860 | ETputs(KTEPS) 1947.84
# Epoch 00903 | Time(s) 0.0068 | Loss 0.1884 | Accuracy 0.7860 | ETputs(KTEPS) 1947.99
# Epoch 00904 | Time(s) 0.0068 | Loss 0.1784 | Accuracy 0.7900 | ETputs(KTEPS) 1948.12
# Epoch 00905 | Time(s) 0.0068 | Loss 0.1930 | Accuracy 0.7880 | ETputs(KTEPS) 1947.90
# Epoch 00906 | Time(s) 0.0068 | Loss 0.1819 | Accuracy 0.7920 | ETputs(KTEPS) 1947.52
# Epoch 00907 | Time(s) 0.0068 | Loss 0.1861 | Accuracy 0.7920 | ETputs(KTEPS) 1946.95
# Epoch 00908 | Time(s) 0.0068 | Loss 0.1666 | Accuracy 0.7900 | ETputs(KTEPS) 1947.07
# Epoch 00909 | Time(s) 0.0068 | Loss 0.1598 | Accuracy 0.7860 | ETputs(KTEPS) 1947.22
# Epoch 00910 | Time(s) 0.0068 | Loss 0.2000 | Accuracy 0.7860 | ETputs(KTEPS) 1947.50
# Epoch 00911 | Time(s) 0.0068 | Loss 0.1668 | Accuracy 0.7900 | ETputs(KTEPS) 1947.75
# Epoch 00912 | Time(s) 0.0068 | Loss 0.2221 | Accuracy 0.7900 | ETputs(KTEPS) 1947.97
# Epoch 00913 | Time(s) 0.0068 | Loss 0.1961 | Accuracy 0.7900 | ETputs(KTEPS) 1948.25
# Epoch 00914 | Time(s) 0.0068 | Loss 0.1486 | Accuracy 0.7880 | ETputs(KTEPS) 1948.40
# Epoch 00915 | Time(s) 0.0068 | Loss 0.2131 | Accuracy 0.7840 | ETputs(KTEPS) 1948.56
# Epoch 00916 | Time(s) 0.0068 | Loss 0.1965 | Accuracy 0.7840 | ETputs(KTEPS) 1948.60
# Epoch 00917 | Time(s) 0.0068 | Loss 0.1755 | Accuracy 0.7840 | ETputs(KTEPS) 1948.65
# Epoch 00918 | Time(s) 0.0068 | Loss 0.1971 | Accuracy 0.7840 | ETputs(KTEPS) 1948.83
# Epoch 00919 | Time(s) 0.0068 | Loss 0.1798 | Accuracy 0.7840 | ETputs(KTEPS) 1949.05
# Epoch 00920 | Time(s) 0.0068 | Loss 0.1817 | Accuracy 0.7840 | ETputs(KTEPS) 1949.25
# Epoch 00921 | Time(s) 0.0068 | Loss 0.1907 | Accuracy 0.7860 | ETputs(KTEPS) 1949.26
# Epoch 00922 | Time(s) 0.0068 | Loss 0.1693 | Accuracy 0.7900 | ETputs(KTEPS) 1949.42
# Epoch 00923 | Time(s) 0.0068 | Loss 0.1695 | Accuracy 0.7880 | ETputs(KTEPS) 1949.49
# Epoch 00924 | Time(s) 0.0068 | Loss 0.1767 | Accuracy 0.7920 | ETputs(KTEPS) 1949.40
# Epoch 00925 | Time(s) 0.0068 | Loss 0.1914 | Accuracy 0.7900 | ETputs(KTEPS) 1949.31
# Epoch 00926 | Time(s) 0.0068 | Loss 0.1896 | Accuracy 0.7880 | ETputs(KTEPS) 1948.91
# Epoch 00927 | Time(s) 0.0068 | Loss 0.1658 | Accuracy 0.7920 | ETputs(KTEPS) 1948.87
# Epoch 00928 | Time(s) 0.0068 | Loss 0.1905 | Accuracy 0.7920 | ETputs(KTEPS) 1949.06
# Epoch 00929 | Time(s) 0.0068 | Loss 0.1983 | Accuracy 0.7900 | ETputs(KTEPS) 1949.19
# Epoch 00930 | Time(s) 0.0068 | Loss 0.2227 | Accuracy 0.7860 | ETputs(KTEPS) 1949.24
# Epoch 00931 | Time(s) 0.0068 | Loss 0.2106 | Accuracy 0.7880 | ETputs(KTEPS) 1949.44
# Epoch 00932 | Time(s) 0.0068 | Loss 0.1744 | Accuracy 0.7880 | ETputs(KTEPS) 1949.54
# Epoch 00933 | Time(s) 0.0068 | Loss 0.1852 | Accuracy 0.7900 | ETputs(KTEPS) 1949.74
# Epoch 00934 | Time(s) 0.0068 | Loss 0.2031 | Accuracy 0.7880 | ETputs(KTEPS) 1949.99
# Epoch 00935 | Time(s) 0.0068 | Loss 0.2007 | Accuracy 0.7840 | ETputs(KTEPS) 1950.05
# Epoch 00936 | Time(s) 0.0068 | Loss 0.2118 | Accuracy 0.7880 | ETputs(KTEPS) 1950.20
# Epoch 00937 | Time(s) 0.0068 | Loss 0.1669 | Accuracy 0.7860 | ETputs(KTEPS) 1950.35
# Epoch 00938 | Time(s) 0.0068 | Loss 0.1662 | Accuracy 0.7880 | ETputs(KTEPS) 1950.61
# Epoch 00939 | Time(s) 0.0068 | Loss 0.1994 | Accuracy 0.7880 | ETputs(KTEPS) 1950.38
# Epoch 00940 | Time(s) 0.0068 | Loss 0.1835 | Accuracy 0.7920 | ETputs(KTEPS) 1950.31
# Epoch 00941 | Time(s) 0.0068 | Loss 0.1765 | Accuracy 0.7920 | ETputs(KTEPS) 1950.09
# Epoch 00942 | Time(s) 0.0068 | Loss 0.2328 | Accuracy 0.7940 | ETputs(KTEPS) 1949.87
# Epoch 00943 | Time(s) 0.0068 | Loss 0.1939 | Accuracy 0.7960 | ETputs(KTEPS) 1949.87
# Epoch 00944 | Time(s) 0.0068 | Loss 0.2066 | Accuracy 0.7960 | ETputs(KTEPS) 1949.66
# Epoch 00945 | Time(s) 0.0068 | Loss 0.1758 | Accuracy 0.7900 | ETputs(KTEPS) 1949.47
# Epoch 00946 | Time(s) 0.0068 | Loss 0.1916 | Accuracy 0.7900 | ETputs(KTEPS) 1949.41
# Epoch 00947 | Time(s) 0.0068 | Loss 0.1774 | Accuracy 0.7840 | ETputs(KTEPS) 1949.48
# Epoch 00948 | Time(s) 0.0068 | Loss 0.1757 | Accuracy 0.7900 | ETputs(KTEPS) 1949.50
# Epoch 00949 | Time(s) 0.0068 | Loss 0.2068 | Accuracy 0.7880 | ETputs(KTEPS) 1949.34
# Epoch 00950 | Time(s) 0.0068 | Loss 0.2055 | Accuracy 0.7900 | ETputs(KTEPS) 1949.41
# Epoch 00951 | Time(s) 0.0068 | Loss 0.2194 | Accuracy 0.7860 | ETputs(KTEPS) 1949.36
# Epoch 00952 | Time(s) 0.0068 | Loss 0.1777 | Accuracy 0.7860 | ETputs(KTEPS) 1949.18
# Epoch 00953 | Time(s) 0.0068 | Loss 0.1781 | Accuracy 0.7900 | ETputs(KTEPS) 1949.15
# Epoch 00954 | Time(s) 0.0068 | Loss 0.1902 | Accuracy 0.7880 | ETputs(KTEPS) 1949.22
# Epoch 00955 | Time(s) 0.0068 | Loss 0.1736 | Accuracy 0.7920 | ETputs(KTEPS) 1949.42
# Epoch 00956 | Time(s) 0.0068 | Loss 0.2024 | Accuracy 0.7920 | ETputs(KTEPS) 1949.39
# Epoch 00957 | Time(s) 0.0068 | Loss 0.1771 | Accuracy 0.7940 | ETputs(KTEPS) 1949.39
# Epoch 00958 | Time(s) 0.0068 | Loss 0.1709 | Accuracy 0.7920 | ETputs(KTEPS) 1949.09
# Epoch 00959 | Time(s) 0.0068 | Loss 0.1627 | Accuracy 0.7880 | ETputs(KTEPS) 1948.64
# Epoch 00960 | Time(s) 0.0068 | Loss 0.1822 | Accuracy 0.7880 | ETputs(KTEPS) 1948.26
# Epoch 00961 | Time(s) 0.0068 | Loss 0.1633 | Accuracy 0.7920 | ETputs(KTEPS) 1948.24
# Epoch 00962 | Time(s) 0.0068 | Loss 0.1867 | Accuracy 0.7900 | ETputs(KTEPS) 1948.49
# Epoch 00963 | Time(s) 0.0068 | Loss 0.1918 | Accuracy 0.7860 | ETputs(KTEPS) 1948.65
# Epoch 00964 | Time(s) 0.0068 | Loss 0.2058 | Accuracy 0.7860 | ETputs(KTEPS) 1948.82
# Epoch 00965 | Time(s) 0.0068 | Loss 0.2138 | Accuracy 0.7900 | ETputs(KTEPS) 1949.13
# Epoch 00966 | Time(s) 0.0068 | Loss 0.1725 | Accuracy 0.7900 | ETputs(KTEPS) 1949.15
# Epoch 00967 | Time(s) 0.0068 | Loss 0.1789 | Accuracy 0.7900 | ETputs(KTEPS) 1949.41
# Epoch 00968 | Time(s) 0.0068 | Loss 0.1778 | Accuracy 0.7880 | ETputs(KTEPS) 1949.63
# Epoch 00969 | Time(s) 0.0068 | Loss 0.1983 | Accuracy 0.7900 | ETputs(KTEPS) 1949.71
# Epoch 00970 | Time(s) 0.0068 | Loss 0.1881 | Accuracy 0.7920 | ETputs(KTEPS) 1949.67
# Epoch 00971 | Time(s) 0.0068 | Loss 0.1776 | Accuracy 0.7900 | ETputs(KTEPS) 1949.90
# Epoch 00972 | Time(s) 0.0068 | Loss 0.2100 | Accuracy 0.7900 | ETputs(KTEPS) 1950.06
# Epoch 00973 | Time(s) 0.0068 | Loss 0.1719 | Accuracy 0.7900 | ETputs(KTEPS) 1950.32
# Epoch 00974 | Time(s) 0.0068 | Loss 0.1836 | Accuracy 0.7900 | ETputs(KTEPS) 1950.46
# Epoch 00975 | Time(s) 0.0068 | Loss 0.1789 | Accuracy 0.7920 | ETputs(KTEPS) 1950.50
# Epoch 00976 | Time(s) 0.0068 | Loss 0.1905 | Accuracy 0.7920 | ETputs(KTEPS) 1950.38
# Epoch 00977 | Time(s) 0.0068 | Loss 0.1705 | Accuracy 0.7900 | ETputs(KTEPS) 1950.33
# Epoch 00978 | Time(s) 0.0068 | Loss 0.1687 | Accuracy 0.7860 | ETputs(KTEPS) 1950.13
# Epoch 00979 | Time(s) 0.0068 | Loss 0.1658 | Accuracy 0.7900 | ETputs(KTEPS) 1950.19
# Epoch 00980 | Time(s) 0.0068 | Loss 0.2013 | Accuracy 0.7860 | ETputs(KTEPS) 1950.15
# Epoch 00981 | Time(s) 0.0068 | Loss 0.1832 | Accuracy 0.7940 | ETputs(KTEPS) 1950.25
# Epoch 00982 | Time(s) 0.0068 | Loss 0.1755 | Accuracy 0.7900 | ETputs(KTEPS) 1950.40
# Epoch 00983 | Time(s) 0.0068 | Loss 0.1814 | Accuracy 0.7880 | ETputs(KTEPS) 1950.68
# Epoch 00984 | Time(s) 0.0068 | Loss 0.2200 | Accuracy 0.7880 | ETputs(KTEPS) 1950.69
# Epoch 00985 | Time(s) 0.0068 | Loss 0.1699 | Accuracy 0.7860 | ETputs(KTEPS) 1950.88
# Epoch 00986 | Time(s) 0.0068 | Loss 0.1862 | Accuracy 0.7900 | ETputs(KTEPS) 1951.09
# Epoch 00987 | Time(s) 0.0068 | Loss 0.1944 | Accuracy 0.7920 | ETputs(KTEPS) 1951.17
# Epoch 00988 | Time(s) 0.0068 | Loss 0.2135 | Accuracy 0.7940 | ETputs(KTEPS) 1951.35
# Epoch 00989 | Time(s) 0.0068 | Loss 0.2056 | Accuracy 0.7920 | ETputs(KTEPS) 1951.46
# Epoch 00990 | Time(s) 0.0068 | Loss 0.1773 | Accuracy 0.7980 | ETputs(KTEPS) 1951.55
# Epoch 00991 | Time(s) 0.0068 | Loss 0.1603 | Accuracy 0.7920 | ETputs(KTEPS) 1951.71
# Epoch 00992 | Time(s) 0.0068 | Loss 0.2013 | Accuracy 0.7940 | ETputs(KTEPS) 1951.73
# Epoch 00993 | Time(s) 0.0068 | Loss 0.1659 | Accuracy 0.7920 | ETputs(KTEPS) 1951.81
# Epoch 00994 | Time(s) 0.0068 | Loss 0.1758 | Accuracy 0.7960 | ETputs(KTEPS) 1951.81
# Epoch 00995 | Time(s) 0.0068 | Loss 0.1739 | Accuracy 0.7960 | ETputs(KTEPS) 1951.83
# Epoch 00996 | Time(s) 0.0068 | Loss 0.1770 | Accuracy 0.7920 | ETputs(KTEPS) 1951.58
# Epoch 00997 | Time(s) 0.0068 | Loss 0.2069 | Accuracy 0.7860 | ETputs(KTEPS) 1951.26
# Epoch 00998 | Time(s) 0.0068 | Loss 0.1874 | Accuracy 0.7900 | ETputs(KTEPS) 1951.06
# Epoch 00999 | Time(s) 0.0068 | Loss 0.1775 | Accuracy 0.7860 | ETputs(KTEPS) 1950.96
#
# Test accuracy 80.10%

# %%
dataset = WindPowerDataset()

# %%
dataset[0]
# Out:
# Graph(num_nodes=94, num_edges=5506,
#       ndata_schemes={'feat': Scheme(shape=(8,), dtype=torch.float64), 'label': Scheme(shape=(), dtype=torch.float64)}
#       edata_schemes={'weight': Scheme(shape=(), dtype=torch.float64)})

# %%
graph = dataset[0]

print(graph)
# Out:
# Graph(num_nodes=94, num_edges=5506,
#       ndata_schemes={'feat': Scheme(shape=(8,), dtype=torch.float64), 'label': Scheme(shape=(), dtype=torch.float64)}
#       edata_schemes={'weight': Scheme(shape=(), dtype=torch.float64)})

# %%
import matplotlib.pyplot as plt
import networkx as nx

def plot_dgl_graph(g):
    G = dgl.to_networkx(g)
    plt.figure(figsize=[10,5])
    options = {
        'node_color': 'blue',
        "edge_color": "red",
        'node_size': 20,
        'width': 1,
    }
    # pos = nx.spring_layout(g)
    # nx.draw_networkx(g, pos, **options)
    nx.draw(G, **options)
    plt.show()
    
plot_dgl_graph(graph)
